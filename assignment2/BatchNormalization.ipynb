# %% [markdown]
# # Batch Normalization
# One way to make deep networks easier to train is to use more sophisticated optimization procedures such as SGD+momentum, RMSProp, or Adam. Another strategy is to change the architecture of the network to make it easier to train.
# One idea along these lines is batch normalization which was proposed by [3] in 2015.
#
# The idea is relatively straightforward. Machine learning methods tend to work better when their input data consists of uncorrelated features with zero mean and unit variance. When training a neural network, we can preprocess the data before feeding it to the network to explicitly decorrelate its features; this will ensure that the first layer of the network sees data that follows a nice distribution. However, even if we preprocess the input data, the activations at deeper layers of the network will likely no longer be decorrelated and will no longer have zero mean or unit variance since they are output from earlier layers in the network. Even worse, during the training process the distribution of features at each layer of the network will shift as the weights of each layer are updated.
#
# The authors of [3] hypothesize that the shifting distribution of features inside deep neural networks may make training deep networks more difficult. To overcome this problem, [3] proposes to insert batch normalization layers into the network. At training time, a batch normalization layer uses a minibatch of data to estimate the mean and standard deviation of each feature. These estimated means and standard deviations are then used to center and normalize the features of the minibatch. A running average of these means and standard deviations is kept during training, and at test time these running averages are used to center and normalize features.
#
# It is possible that this normalization strategy could reduce the representational power of the network, since it may sometimes be optimal for certain layers to have features that are not zero-mean or unit variance. To this end, the batch normalization layer includes learnable shift and scale parameters for each feature dimension.
#
# [3] [Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing
# Internal Covariate Shift", ICML 2015.](https://arxiv.org/abs/1502.03167)

# %%
# As usual, a bit of setup
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def print_mean_std(x,axis=0):
    print('  means: ', x.mean(axis=axis))
    print('  stds:  ', x.std(axis=axis))
    print()

# %%
# Load the (preprocessed) CIFAR10 data.
data = get_CIFAR10_data()
for k, v in data.items():
  print('%s: ' % k, v.shape)
# Out:
# X_train:  (49000, 3, 32, 32)
# y_train:  (49000,)
# X_val:  (1000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# ## Batch normalization: forward
# In the file `cs231n/layers.py`, implement the batch normalization forward pass in the function `batchnorm_forward`. Once you have done so, run the following to test your implementation.
#
# Referencing the paper linked to above would be helpful!

# %%
# Check the training-time forward pass by checking means and variances
# of features both before and after batch normalization   

# Simulate the forward pass for a two-layer network
np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)

print('Before batch normalization:')
print_mean_std(a,axis=0)

gamma = np.ones((D3,))
beta = np.zeros((D3,))
# Means should be close to zero and stds close to one
print('After batch normalization (gamma=1, beta=0)')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)

gamma = np.asarray([1.0, 2.0, 3.0])
beta = np.asarray([11.0, 12.0, 13.0])
# Now means should be close to beta and stds close to gamma
print('After batch normalization (gamma=', gamma, ', beta=', beta, ')')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)
# Out:
# Before batch normalization:
#   means:  [ -2.3814598  -13.18038246   1.91780462]
#   stds:   [ 27.18502186  34.21455511  37.68611762]
#
# After batch normalization (gamma=1, beta=0)
#   means:  [  4.21884749e-17   5.10702591e-17  -3.51801921e-17]
#   stds:   [ 0.99999999  1.          1.        ]
#
# After batch normalization (gamma= [ 1.  2.  3.] , beta= [ 11.  12.  13.] )
#   means:  [ 11.  12.  13.]
#   stds:   [ 0.99999999  1.99999999  2.99999999]

# %%
# Check the test-time forward pass by running the training-time
# forward pass many times to warm up the running averages, and then
# checking the means and variances of activations after a test-time
# forward pass.

np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)

bn_param = {'mode': 'train'}
gamma = np.ones(D3)
beta = np.zeros(D3)

for t in range(50):
  X = np.random.randn(N, D1)
  a = np.maximum(0, X.dot(W1)).dot(W2)
  batchnorm_forward(a, gamma, beta, bn_param)

bn_param['mode'] = 'test'
X = np.random.randn(N, D1)
a = np.maximum(0, X.dot(W1)).dot(W2)
a_norm, _ = batchnorm_forward(a, gamma, beta, bn_param)

# Means should be close to zero and stds close to one, but will be
# noisier than training-time forward passes.
print('After batch normalization (test-time):')
print_mean_std(a_norm,axis=0)
# Out:
# After batch normalization (test-time):
#   means:  [-0.03927354 -0.04349152 -0.10452688]
#   stds:   [ 1.01531428  1.01238373  0.97819988]

# %% [markdown]
# ## Batch normalization: backward
# Now implement the backward pass for batch normalization in the function `batchnorm_backward`.
#
# To derive the backward pass you should write out the computation graph for batch normalization and backprop through each of the intermediate nodes. Some intermediates may have multiple outgoing branches; make sure to sum gradients across these branches in the backward pass.
#
# Once you have finished, run the following to numerically check your backward pass.

# %%
# Gradient check batchnorm backward pass
np.random.seed(231)
N, D = 4, 5
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

bn_param = {'mode': 'train'}
fx = lambda x: batchnorm_forward(x, gamma, beta, bn_param)[0]
fg = lambda a: batchnorm_forward(x, a, beta, bn_param)[0]
fb = lambda b: batchnorm_forward(x, gamma, b, bn_param)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
da_num = eval_numerical_gradient_array(fg, gamma.copy(), dout)
db_num = eval_numerical_gradient_array(fb, beta.copy(), dout)

_, cache = batchnorm_forward(x, gamma, beta, bn_param)
dx, dgamma, dbeta = batchnorm_backward(dout, cache)
#You should expect to see relative errors between 1e-13 and 1e-8
print('dx error: ', rel_error(dx_num, dx))
print('dgamma error: ', rel_error(da_num, dgamma))
print('dbeta error: ', rel_error(db_num, dbeta))
# Out:
# dx error:  1.7029238452e-09
# dgamma error:  7.42041421625e-13
# dbeta error:  2.87950576558e-12

# %% [markdown]
# ## Batch normalization: alternative backward
# In class we talked about two different implementations for the sigmoid backward pass. One strategy is to write out a computation graph composed of simple operations and backprop through all intermediate values. Another strategy is to work out the derivatives on paper. For example, you can derive a very simple formula for the sigmoid function's backward pass by simplifying gradients on paper.
#
# Surprisingly, it turns out that you can do a similar simplification for the batch normalization backward pass too.
# Given a set of inputs $X=\begin{bmatrix}x_1\\x_2\\...\\x_N\end{bmatrix}$,
# we first calculate the mean $\mu=\frac{1}{N}\sum_{k=1}^N x_k$ and variance $v=\frac{1}{N}\sum_{k=1}^N (x_k-\mu)^2.$
# With $\mu$ and $v$ calculated, we can calculate the standard deviation $\sigma=\sqrt{v+\epsilon}$  and normalized data $Y$ with $y_i=\frac{x_i-\mu}{\sigma}.$
#
#
# The meat of our problem is to get $\frac{\partial L}{\partial X}$ from the upstream gradient $\frac{\partial L}{\partial Y}.$ It might be challenging to directly reason about the gradients over $X$ and $Y$ - try reasoning about it in terms of $x_i$ and $y_i$ first.
#
# You will need to come up with the derivations for $\frac{\partial L}{\partial x_i}$, by relying on the Chain Rule to first calculate the intermediate $\frac{\partial \mu}{\partial x_i}, \frac{\partial v}{\partial x_i}, \frac{\partial \sigma}{\partial x_i},$ then assemble these pieces to calculate $\frac{\partial y_i}{\partial x_i}$. You should make sure each of the intermediary steps are all as simple as possible.
#
# After doing so, implement the simplified batch normalization backward pass in the function `batchnorm_backward_alt` and compare the two implementations by running the following. Your two implementations should compute nearly identical results, but the alternative implementation should be a bit faster.

# %%
np.random.seed(231)
N, D = 100, 500
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

bn_param = {'mode': 'train'}
out, cache = batchnorm_forward(x, gamma, beta, bn_param)

t1 = time.time()
dx1, dgamma1, dbeta1 = batchnorm_backward(dout, cache)
t2 = time.time()
dx2, dgamma2, dbeta2 = batchnorm_backward_alt(dout, cache)
t3 = time.time()

print('dx difference: ', rel_error(dx1, dx2))
print('dgamma difference: ', rel_error(dgamma1, dgamma2))
print('dbeta difference: ', rel_error(dbeta1, dbeta2))
print('speedup: %.2fx' % ((t2 - t1) / (t3 - t2)))
# Out:
# dx difference:  1.06890440382e-12
# dgamma difference:  0.0
# dbeta difference:  0.0
# speedup: 1.50x

# %% [markdown]
# ## Fully Connected Nets with Batch Normalization
# Now that you have a working implementation for batch normalization, go back to your `FullyConnectedNet` in the file `cs231n/classifiers/fc_net.py`. Modify your implementation to add batch normalization.
#
# Concretely, when the `normalization` flag is set to `"batchnorm"` in the constructor, you should insert a batch normalization layer before each ReLU nonlinearity. The outputs from the last layer of the network should not be normalized. Once you are done, run the following to gradient-check your implementation.
#
# HINT: You might find it useful to define an additional helper layer similar to those in the file `cs231n/layer_utils.py`. If you decide to do so, do it in the file `cs231n/classifiers/fc_net.py`.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

# You should expect losses between 1e-4~1e-10 for W, 
# losses between 1e-08~1e-10 for b,
# and losses between 1e-08~1e-09 for beta and gammas.
for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64,
                            normalization='batchnorm')

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  if reg == 0: print()
# Out:
# Running check with reg =  0
# Initial loss:  2.26119551013
# W1 relative error: 1.10e-04
# W2 relative error: 2.85e-06
# W3 relative error: 3.92e-10
# b1 relative error: 4.44e-08
# b2 relative error: 5.55e-09
# b3 relative error: 1.01e-10
# beta1 relative error: 7.85e-09
# beta2 relative error: 1.07e-09
# gamma1 relative error: 6.44e-09
# gamma2 relative error: 1.56e-09
#
# Running check with reg =  3.14
# Initial loss:  6.99653322011
# W1 relative error: 1.98e-06
# W2 relative error: 2.28e-06
# W3 relative error: 1.11e-08
# b1 relative error: 4.44e-08
# b2 relative error: 1.39e-09
# b3 relative error: 2.23e-10
# beta1 relative error: 6.65e-09
# beta2 relative error: 5.69e-09
# gamma1 relative error: 5.94e-09
# gamma2 relative error: 4.14e-09

# %% [markdown]
# # Batchnorm for deep networks
# Run the following to train a six-layer network on a subset of 1000 training examples both with and without batch normalization.

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [100, 100, 100, 100, 100]

num_train = 1000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 2e-2
bn_model = FullyConnectedNet(hidden_dims, reg=3e-2, weight_scale=weight_scale, normalization='batchnorm')
model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)

bn_solver = Solver(bn_model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True,print_every=20)
bn_solver.train()

print()

solver = Solver(model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()
# Out:
# (Iteration 0 / 200) loss: 4.425055
# (Epoch 0 / 10) train acc: 0.106000; val_acc: 0.118000
# (Epoch 1 / 10) train acc: 0.331000; val_acc: 0.244000
# (Iteration 20 / 200) loss: 2.881354
# (Epoch 2 / 10) train acc: 0.395000; val_acc: 0.293000
# (Iteration 40 / 200) loss: 2.566075
# (Epoch 3 / 10) train acc: 0.397000; val_acc: 0.269000
# (Iteration 60 / 200) loss: 2.411498
# (Epoch 4 / 10) train acc: 0.453000; val_acc: 0.296000
# (Iteration 80 / 200) loss: 1.968045
# (Epoch 5 / 10) train acc: 0.508000; val_acc: 0.313000
# (Iteration 100 / 200) loss: 1.821501
# (Epoch 6 / 10) train acc: 0.548000; val_acc: 0.300000
# (Iteration 120 / 200) loss: 1.796629
# (Epoch 7 / 10) train acc: 0.577000; val_acc: 0.298000
# (Iteration 140 / 200) loss: 1.804670
# (Epoch 8 / 10) train acc: 0.601000; val_acc: 0.309000
# (Iteration 160 / 200) loss: 1.580273
# (Epoch 9 / 10) train acc: 0.631000; val_acc: 0.317000
# (Iteration 180 / 200) loss: 1.810511
# (Epoch 10 / 10) train acc: 0.623000; val_acc: 0.316000
#
# (Iteration 0 / 200) loss: 2.302332
# (Epoch 0 / 10) train acc: 0.126000; val_acc: 0.130000
# (Epoch 1 / 10) train acc: 0.249000; val_acc: 0.234000
# (Iteration 20 / 200) loss: 2.001350
# (Epoch 2 / 10) train acc: 0.294000; val_acc: 0.232000
# (Iteration 40 / 200) loss: 1.848141
# (Epoch 3 / 10) train acc: 0.355000; val_acc: 0.276000
# (Iteration 60 / 200) loss: 1.720592
# (Epoch 4 / 10) train acc: 0.385000; val_acc: 0.288000
# (Iteration 80 / 200) loss: 1.331904
# (Epoch 5 / 10) train acc: 0.441000; val_acc: 0.295000
# (Iteration 100 / 200) loss: 1.737315
# (Epoch 6 / 10) train acc: 0.453000; val_acc: 0.309000
# (Iteration 120 / 200) loss: 1.428344
# (Epoch 7 / 10) train acc: 0.511000; val_acc: 0.312000
# (Iteration 140 / 200) loss: 1.321532
# (Epoch 8 / 10) train acc: 0.547000; val_acc: 0.304000
# (Iteration 160 / 200) loss: 1.115160
# (Epoch 9 / 10) train acc: 0.608000; val_acc: 0.330000
# (Iteration 180 / 200) loss: 0.927217
# (Epoch 10 / 10) train acc: 0.665000; val_acc: 0.332000

# %% [markdown]
# Run the following to visualize the results from two networks trained above. You should find that using batch normalization helps the network to converge much faster.

# %%
def plot_training_history(title, label, baseline, bn_solvers, plot_fn, bl_marker='.', bn_marker='.', labels=None):
    """utility function for plotting training history"""
    plt.title(title)
    plt.xlabel(label)
    bn_plots = [plot_fn(bn_solver) for bn_solver in bn_solvers]
    bl_plot = plot_fn(baseline)
    num_bn = len(bn_plots)
    for i in range(num_bn):
        label='with_norm'
        if labels is not None:
            label += str(labels[i])
        plt.plot(bn_plots[i], bn_marker, label=label)
    label='baseline'
    if labels is not None:
        label += str(labels[0])
    plt.plot(bl_plot, bl_marker, label=label)
    plt.legend(loc='lower center', ncol=num_bn+1) 

    
plt.subplot(3, 1, 1)
plot_training_history('Training loss','Iteration', solver, [bn_solver], \
                      lambda x: x.loss_history, bl_marker='o', bn_marker='o')
plt.subplot(3, 1, 2)
plot_training_history('Training accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.train_acc_history, bl_marker='-o', bn_marker='-o')
plt.subplot(3, 1, 3)
plot_training_history('Validation accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.val_acc_history, bl_marker='-o', bn_marker='-o')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Batch normalization and initialization
# We will now run a small experiment to study the interaction of batch normalization and weight initialization.
#
# The first cell will train 8-layer networks both with and without batch normalization using different scales for weight initialization. The second layer will plot training accuracy, validation set accuracy, and training loss as a function of the weight initialization scale.

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [50, 50, 50, 50, 50, 50, 50]
num_train = 1000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

bn_solvers_ws = {}
solvers_ws = {}
weight_scales = np.logspace(-4, 0, num=20)
for i, weight_scale in enumerate(weight_scales):
  print('Running weight scale %d / %d' % (i + 1, len(weight_scales)))
  bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization='batchnorm')
  model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)

  bn_solver = Solver(bn_model, small_data,
                  num_epochs=30, batch_size=50,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 1e-3,
                  },
                  verbose=True, print_every=5)
  bn_solver.train()
  print()
  bn_solvers_ws[weight_scale] = bn_solver

  solver = Solver(model, small_data,
                  num_epochs=30, batch_size=50,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 1e-3,
                  },
                  verbose=True, print_every=5)
  solver.train()
  print()
  solvers_ws[weight_scale] = solver
# Out:
# Running weight scale 1 / 20
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.099000; val_acc: 0.113000
# (Iteration 5 / 600) loss: 2.303321
# (Iteration 10 / 600) loss: 2.307793
# (Iteration 15 / 600) loss: 2.303932
# (Epoch 1 / 30) train acc: 0.118000; val_acc: 0.110000
# (Iteration 20 / 600) loss: 2.298175
# (Iteration 25 / 600) loss: 2.266838
# (Iteration 30 / 600) loss: 2.256270
# (Iteration 35 / 600) loss: 2.301306
# (Epoch 2 / 30) train acc: 0.163000; val_acc: 0.156000
# (Iteration 40 / 600) loss: 2.269425
# (Iteration 45 / 600) loss: 2.154073
# (Iteration 50 / 600) loss: 1.983531
# (Iteration 55 / 600) loss: 2.130487
# (Epoch 3 / 30) train acc: 0.230000; val_acc: 0.209000
# (Iteration 60 / 600) loss: 2.044248
# (Iteration 65 / 600) loss: 2.122051
# (Iteration 70 / 600) loss: 2.051451
# (Iteration 75 / 600) loss: 2.024159
# (Epoch 4 / 30) train acc: 0.208000; val_acc: 0.195000
# (Iteration 80 / 600) loss: 2.086942
# (Iteration 85 / 600) loss: 1.990154
# (Iteration 90 / 600) loss: 1.881135
# (Iteration 95 / 600) loss: 1.972358
# (Epoch 5 / 30) train acc: 0.231000; val_acc: 0.211000
# (Iteration 100 / 600) loss: 1.853433
# (Iteration 105 / 600) loss: 1.874282
# (Iteration 110 / 600) loss: 1.953027
# (Iteration 115 / 600) loss: 1.928913
# (Epoch 6 / 30) train acc: 0.268000; val_acc: 0.228000
# (Iteration 120 / 600) loss: 2.011054
# (Iteration 125 / 600) loss: 1.856069
# (Iteration 130 / 600) loss: 1.834272
# (Iteration 135 / 600) loss: 1.821021
# (Epoch 7 / 30) train acc: 0.276000; val_acc: 0.229000
# (Iteration 140 / 600) loss: 1.917465
# (Iteration 145 / 600) loss: 1.802471
# (Iteration 150 / 600) loss: 1.766373
# (Iteration 155 / 600) loss: 1.949730
# (Epoch 8 / 30) train acc: 0.277000; val_acc: 0.236000
# (Iteration 160 / 600) loss: 1.723336
# (Iteration 165 / 600) loss: 1.700816
# (Iteration 170 / 600) loss: 1.787018
# (Iteration 175 / 600) loss: 1.651771
# (Epoch 9 / 30) train acc: 0.327000; val_acc: 0.266000
# (Iteration 180 / 600) loss: 1.869974
# (Iteration 185 / 600) loss: 1.763295
# (Iteration 190 / 600) loss: 1.806930
# (Iteration 195 / 600) loss: 1.840080
# (Epoch 10 / 30) train acc: 0.317000; val_acc: 0.248000
# (Iteration 200 / 600) loss: 1.712524
# (Iteration 205 / 600) loss: 1.599207
# (Iteration 210 / 600) loss: 1.731646
# (Iteration 215 / 600) loss: 1.799477
# (Epoch 11 / 30) train acc: 0.341000; val_acc: 0.271000
# (Iteration 220 / 600) loss: 1.666618
# (Iteration 225 / 600) loss: 1.623124
# (Iteration 230 / 600) loss: 1.634054
# (Iteration 235 / 600) loss: 1.768001
# (Epoch 12 / 30) train acc: 0.339000; val_acc: 0.256000
# (Iteration 240 / 600) loss: 1.666810
# (Iteration 245 / 600) loss: 1.603494
# (Iteration 250 / 600) loss: 1.710197
# (Iteration 255 / 600) loss: 1.517158
# (Epoch 13 / 30) train acc: 0.376000; val_acc: 0.274000
# (Iteration 260 / 600) loss: 1.519013
# (Iteration 265 / 600) loss: 1.531937
# (Iteration 270 / 600) loss: 1.502614
# (Iteration 275 / 600) loss: 1.440959
# (Epoch 14 / 30) train acc: 0.388000; val_acc: 0.261000
# (Iteration 280 / 600) loss: 1.530925
# (Iteration 285 / 600) loss: 1.579016
# (Iteration 290 / 600) loss: 1.715760
# (Iteration 295 / 600) loss: 1.519397
# (Epoch 15 / 30) train acc: 0.377000; val_acc: 0.263000
# (Iteration 300 / 600) loss: 1.830201
# (Iteration 305 / 600) loss: 1.527781
# (Iteration 310 / 600) loss: 1.557470
# (Iteration 315 / 600) loss: 1.466544
# (Epoch 16 / 30) train acc: 0.412000; val_acc: 0.273000
# (Iteration 320 / 600) loss: 1.701996
# (Iteration 325 / 600) loss: 1.392331
# (Iteration 330 / 600) loss: 1.397940
# (Iteration 335 / 600) loss: 1.440393
# (Epoch 17 / 30) train acc: 0.424000; val_acc: 0.276000
# (Iteration 340 / 600) loss: 1.678584
# (Iteration 345 / 600) loss: 1.419672
# (Iteration 350 / 600) loss: 1.657507
# (Iteration 355 / 600) loss: 1.561110
# (Epoch 18 / 30) train acc: 0.407000; val_acc: 0.241000
# (Iteration 360 / 600) loss: 1.532009
# (Iteration 365 / 600) loss: 1.385519
# (Iteration 370 / 600) loss: 1.604196
# (Iteration 375 / 600) loss: 1.296684
# (Epoch 19 / 30) train acc: 0.445000; val_acc: 0.256000
# (Iteration 380 / 600) loss: 1.389346
# (Iteration 385 / 600) loss: 1.659634
# (Iteration 390 / 600) loss: 1.251612
# (Iteration 395 / 600) loss: 1.280276
# (Epoch 20 / 30) train acc: 0.436000; val_acc: 0.265000
# (Iteration 400 / 600) loss: 1.364026
# (Iteration 405 / 600) loss: 1.363338
# (Iteration 410 / 600) loss: 1.493055
# (Iteration 415 / 600) loss: 1.445441
# (Epoch 21 / 30) train acc: 0.459000; val_acc: 0.266000
# (Iteration 420 / 600) loss: 1.346353
# (Iteration 425 / 600) loss: 1.490732
# (Iteration 430 / 600) loss: 1.253450
# (Iteration 435 / 600) loss: 1.277336
# (Epoch 22 / 30) train acc: 0.470000; val_acc: 0.261000
# (Iteration 440 / 600) loss: 1.274919
# (Iteration 445 / 600) loss: 1.507965
# (Iteration 450 / 600) loss: 1.218292
# (Iteration 455 / 600) loss: 1.443750
# (Epoch 23 / 30) train acc: 0.465000; val_acc: 0.262000
# (Iteration 460 / 600) loss: 1.310902
# (Iteration 465 / 600) loss: 1.370394
# (Iteration 470 / 600) loss: 1.550717
# (Iteration 475 / 600) loss: 1.247813
# (Epoch 24 / 30) train acc: 0.480000; val_acc: 0.258000
# (Iteration 480 / 600) loss: 1.355022
# (Iteration 485 / 600) loss: 1.440495
# (Iteration 490 / 600) loss: 1.227193
# (Iteration 495 / 600) loss: 1.418687
# (Epoch 25 / 30) train acc: 0.490000; val_acc: 0.265000
# (Iteration 500 / 600) loss: 1.504980
# (Iteration 505 / 600) loss: 1.178115
# (Iteration 510 / 600) loss: 1.275189
# (Iteration 515 / 600) loss: 1.189027
# (Epoch 26 / 30) train acc: 0.515000; val_acc: 0.259000
# (Iteration 520 / 600) loss: 1.395853
# (Iteration 525 / 600) loss: 1.322238
# (Iteration 530 / 600) loss: 1.115611
# (Iteration 535 / 600) loss: 1.234667
# (Epoch 27 / 30) train acc: 0.487000; val_acc: 0.267000
# (Iteration 540 / 600) loss: 1.224979
# (Iteration 545 / 600) loss: 1.218961
# (Iteration 550 / 600) loss: 1.148183
# (Iteration 555 / 600) loss: 1.144926
# (Epoch 28 / 30) train acc: 0.505000; val_acc: 0.261000
# (Iteration 560 / 600) loss: 1.158897
# (Iteration 565 / 600) loss: 1.231898
# (Iteration 570 / 600) loss: 1.319482
# (Iteration 575 / 600) loss: 1.153512
# (Epoch 29 / 30) train acc: 0.532000; val_acc: 0.244000
# (Iteration 580 / 600) loss: 1.021382
# (Iteration 585 / 600) loss: 1.178592
# (Iteration 590 / 600) loss: 1.048914
# (Iteration 595 / 600) loss: 1.096419
# (Epoch 30 / 30) train acc: 0.515000; val_acc: 0.255000
#
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 5 / 600) loss: 2.303070
# (Iteration 10 / 600) loss: 2.301570
# (Iteration 15 / 600) loss: 2.304447
# (Epoch 1 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 20 / 600) loss: 2.301345
# (Iteration 25 / 600) loss: 2.301967
# (Iteration 30 / 600) loss: 2.301226
# (Iteration 35 / 600) loss: 2.299275
# (Epoch 2 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 40 / 600) loss: 2.301760
# (Iteration 45 / 600) loss: 2.298958
# (Iteration 50 / 600) loss: 2.303707
# (Iteration 55 / 600) loss: 2.299184
# (Epoch 3 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 60 / 600) loss: 2.295953
# (Iteration 65 / 600) loss: 2.303758
# (Iteration 70 / 600) loss: 2.298972
# (Iteration 75 / 600) loss: 2.300661
# (Epoch 4 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 80 / 600) loss: 2.304838
# (Iteration 85 / 600) loss: 2.303115
# (Iteration 90 / 600) loss: 2.305163
# (Iteration 95 / 600) loss: 2.296393
# (Epoch 5 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 100 / 600) loss: 2.294531
# (Iteration 105 / 600) loss: 2.300410
# (Iteration 110 / 600) loss: 2.297773
# (Iteration 115 / 600) loss: 2.295819
# (Epoch 6 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 120 / 600) loss: 2.309907
# (Iteration 125 / 600) loss: 2.304802
# (Iteration 130 / 600) loss: 2.299207
# (Iteration 135 / 600) loss: 2.303891
# (Epoch 7 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 140 / 600) loss: 2.305174
# (Iteration 145 / 600) loss: 2.304827
# (Iteration 150 / 600) loss: 2.299379
# (Iteration 155 / 600) loss: 2.301836
# (Epoch 8 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 160 / 600) loss: 2.299377
# (Iteration 165 / 600) loss: 2.308827
# (Iteration 170 / 600) loss: 2.303983
# (Iteration 175 / 600) loss: 2.302084
# (Epoch 9 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 180 / 600) loss: 2.295956
# (Iteration 185 / 600) loss: 2.302818
# (Iteration 190 / 600) loss: 2.298354
# (Iteration 195 / 600) loss: 2.297152
# (Epoch 10 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 200 / 600) loss: 2.307634
# (Iteration 205 / 600) loss: 2.296526
# (Iteration 210 / 600) loss: 2.296223
# (Iteration 215 / 600) loss: 2.291292
# (Epoch 11 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 220 / 600) loss: 2.298785
# (Iteration 225 / 600) loss: 2.304863
# (Iteration 230 / 600) loss: 2.311583
# (Iteration 235 / 600) loss: 2.297700
# (Epoch 12 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 240 / 600) loss: 2.298770
# (Iteration 245 / 600) loss: 2.299715
# (Iteration 250 / 600) loss: 2.305781
# (Iteration 255 / 600) loss: 2.302291
# (Epoch 13 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 260 / 600) loss: 2.298636
# (Iteration 265 / 600) loss: 2.309671
# (Iteration 270 / 600) loss: 2.297029
# (Iteration 275 / 600) loss: 2.297682
# (Epoch 14 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 280 / 600) loss: 2.291655
# (Iteration 285 / 600) loss: 2.297875
# (Iteration 290 / 600) loss: 2.299698
# (Iteration 295 / 600) loss: 2.300289
# (Epoch 15 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 300 / 600) loss: 2.303314
# (Iteration 305 / 600) loss: 2.303846
# (Iteration 310 / 600) loss: 2.312345
# (Iteration 315 / 600) loss: 2.293102
# (Epoch 16 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 320 / 600) loss: 2.291592
# (Iteration 325 / 600) loss: 2.303944
# (Iteration 330 / 600) loss: 2.292683
# (Iteration 335 / 600) loss: 2.305753
# (Epoch 17 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 340 / 600) loss: 2.296266
# (Iteration 345 / 600) loss: 2.296139
# (Iteration 350 / 600) loss: 2.302379
# (Iteration 355 / 600) loss: 2.311142
# (Epoch 18 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 360 / 600) loss: 2.303342
# (Iteration 365 / 600) loss: 2.305193
# (Iteration 370 / 600) loss: 2.306609
# (Iteration 375 / 600) loss: 2.300445
# (Epoch 19 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 380 / 600) loss: 2.317207
# (Iteration 385 / 600) loss: 2.313547
# (Iteration 390 / 600) loss: 2.305469
# (Iteration 395 / 600) loss: 2.305749
# (Epoch 20 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 400 / 600) loss: 2.288582
# (Iteration 405 / 600) loss: 2.303768
# (Iteration 410 / 600) loss: 2.297832
# (Iteration 415 / 600) loss: 2.298017
# (Epoch 21 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 420 / 600) loss: 2.294534
# (Iteration 425 / 600) loss: 2.293999
# (Iteration 430 / 600) loss: 2.305061
# (Iteration 435 / 600) loss: 2.287487
# (Epoch 22 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 440 / 600) loss: 2.304085
# (Iteration 445 / 600) loss: 2.301167
# (Iteration 450 / 600) loss: 2.297484
# (Iteration 455 / 600) loss: 2.294131
# (Epoch 23 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 460 / 600) loss: 2.299664
# (Iteration 465 / 600) loss: 2.302306
# (Iteration 470 / 600) loss: 2.302141
# (Iteration 475 / 600) loss: 2.302263
# (Epoch 24 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 480 / 600) loss: 2.307084
# (Iteration 485 / 600) loss: 2.297164
# (Iteration 490 / 600) loss: 2.301168
# (Iteration 495 / 600) loss: 2.295113
# (Epoch 25 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 500 / 600) loss: 2.289432
# (Iteration 505 / 600) loss: 2.305922
# (Iteration 510 / 600) loss: 2.293684
# (Iteration 515 / 600) loss: 2.300103
# (Epoch 26 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 520 / 600) loss: 2.293358
# (Iteration 525 / 600) loss: 2.298661
# (Iteration 530 / 600) loss: 2.299724
# (Iteration 535 / 600) loss: 2.299728
# (Epoch 27 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 540 / 600) loss: 2.293042
# (Iteration 545 / 600) loss: 2.300941
# (Iteration 550 / 600) loss: 2.299739
# (Iteration 555 / 600) loss: 2.290231
# (Epoch 28 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 560 / 600) loss: 2.293132
# (Iteration 565 / 600) loss: 2.302759
# (Iteration 570 / 600) loss: 2.300707
# (Iteration 575 / 600) loss: 2.287927
# (Epoch 29 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 580 / 600) loss: 2.298201
# (Iteration 585 / 600) loss: 2.306614
# (Iteration 590 / 600) loss: 2.294719
# (Iteration 595 / 600) loss: 2.290821
# (Epoch 30 / 30) train acc: 0.112000; val_acc: 0.119000
#
# Running weight scale 2 / 20
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.135000; val_acc: 0.130000
# (Iteration 5 / 600) loss: 2.302074
# (Iteration 10 / 600) loss: 2.294412
# (Iteration 15 / 600) loss: 2.286585
# (Epoch 1 / 30) train acc: 0.134000; val_acc: 0.119000
# (Iteration 20 / 600) loss: 2.302106
# (Iteration 25 / 600) loss: 2.219323
# (Iteration 30 / 600) loss: 2.248011
# (Iteration 35 / 600) loss: 2.240316
# (Epoch 2 / 30) train acc: 0.169000; val_acc: 0.149000
# (Iteration 40 / 600) loss: 2.201702
# (Iteration 45 / 600) loss: 2.064484
# (Iteration 50 / 600) loss: 2.095367
# (Iteration 55 / 600) loss: 2.046725
# (Epoch 3 / 30) train acc: 0.197000; val_acc: 0.157000
# (Iteration 60 / 600) loss: 2.072387
# (Iteration 65 / 600) loss: 2.069231
# (Iteration 70 / 600) loss: 2.125793
# (Iteration 75 / 600) loss: 2.174610
# (Epoch 4 / 30) train acc: 0.193000; val_acc: 0.164000
# (Iteration 80 / 600) loss: 2.163658
# (Iteration 85 / 600) loss: 1.988787
# (Iteration 90 / 600) loss: 1.973931
# (Iteration 95 / 600) loss: 2.151581
# (Epoch 5 / 30) train acc: 0.191000; val_acc: 0.188000
# (Iteration 100 / 600) loss: 2.076067
# (Iteration 105 / 600) loss: 1.908559
# (Iteration 110 / 600) loss: 2.015901
# (Iteration 115 / 600) loss: 1.998311
# (Epoch 6 / 30) train acc: 0.229000; val_acc: 0.205000
# (Iteration 120 / 600) loss: 1.966316
# (Iteration 125 / 600) loss: 1.930187
# (Iteration 130 / 600) loss: 1.919634
# (Iteration 135 / 600) loss: 2.034314
# (Epoch 7 / 30) train acc: 0.237000; val_acc: 0.213000
# (Iteration 140 / 600) loss: 2.058360
# (Iteration 145 / 600) loss: 2.062105
# (Iteration 150 / 600) loss: 1.932401
# (Iteration 155 / 600) loss: 1.878609
# (Epoch 8 / 30) train acc: 0.256000; val_acc: 0.217000
# (Iteration 160 / 600) loss: 2.131476
# (Iteration 165 / 600) loss: 1.980582
# (Iteration 170 / 600) loss: 1.890314
# (Iteration 175 / 600) loss: 1.966996
# (Epoch 9 / 30) train acc: 0.255000; val_acc: 0.195000
# (Iteration 180 / 600) loss: 1.729761
# (Iteration 185 / 600) loss: 1.818569
# (Iteration 190 / 600) loss: 2.060582
# (Iteration 195 / 600) loss: 1.905470
# (Epoch 10 / 30) train acc: 0.285000; val_acc: 0.233000
# (Iteration 200 / 600) loss: 1.791795
# (Iteration 205 / 600) loss: 1.782579
# (Iteration 210 / 600) loss: 1.789164
# (Iteration 215 / 600) loss: 1.932864
# (Epoch 11 / 30) train acc: 0.284000; val_acc: 0.236000
# (Iteration 220 / 600) loss: 1.708416
# (Iteration 225 / 600) loss: 1.799793
# (Iteration 230 / 600) loss: 1.823214
# (Iteration 235 / 600) loss: 1.842707
# (Epoch 12 / 30) train acc: 0.283000; val_acc: 0.203000
# (Iteration 240 / 600) loss: 1.660597
# (Iteration 245 / 600) loss: 1.639051
# (Iteration 250 / 600) loss: 1.834937
# (Iteration 255 / 600) loss: 1.782393
# (Epoch 13 / 30) train acc: 0.280000; val_acc: 0.206000
# (Iteration 260 / 600) loss: 1.947794
# (Iteration 265 / 600) loss: 1.992175
# (Iteration 270 / 600) loss: 1.763638
# (Iteration 275 / 600) loss: 1.817947
# (Epoch 14 / 30) train acc: 0.299000; val_acc: 0.235000
# (Iteration 280 / 600) loss: 1.875125
# (Iteration 285 / 600) loss: 1.783911
# (Iteration 290 / 600) loss: 1.810860
# (Iteration 295 / 600) loss: 1.727657
# (Epoch 15 / 30) train acc: 0.302000; val_acc: 0.236000
# (Iteration 300 / 600) loss: 1.623834
# (Iteration 305 / 600) loss: 1.880438
# (Iteration 310 / 600) loss: 1.855420
# (Iteration 315 / 600) loss: 1.763596
# (Epoch 16 / 30) train acc: 0.302000; val_acc: 0.234000
# (Iteration 320 / 600) loss: 1.883949
# (Iteration 325 / 600) loss: 1.995786
# (Iteration 330 / 600) loss: 1.760855
# (Iteration 335 / 600) loss: 1.702868
# (Epoch 17 / 30) train acc: 0.316000; val_acc: 0.243000
# (Iteration 340 / 600) loss: 1.642237
# (Iteration 345 / 600) loss: 1.796707
# (Iteration 350 / 600) loss: 1.622315
# (Iteration 355 / 600) loss: 1.618272
# (Epoch 18 / 30) train acc: 0.311000; val_acc: 0.239000
# (Iteration 360 / 600) loss: 1.565916
# (Iteration 365 / 600) loss: 1.914111
# (Iteration 370 / 600) loss: 1.588549
# (Iteration 375 / 600) loss: 1.641755
# (Epoch 19 / 30) train acc: 0.324000; val_acc: 0.248000
# (Iteration 380 / 600) loss: 1.566691
# (Iteration 385 / 600) loss: 1.693604
# (Iteration 390 / 600) loss: 1.697722
# (Iteration 395 / 600) loss: 1.585133
# (Epoch 20 / 30) train acc: 0.329000; val_acc: 0.218000
# (Iteration 400 / 600) loss: 1.576375
# (Iteration 405 / 600) loss: 1.479738
# (Iteration 410 / 600) loss: 1.422688
# (Iteration 415 / 600) loss: 1.613766
# (Epoch 21 / 30) train acc: 0.357000; val_acc: 0.229000
# (Iteration 420 / 600) loss: 1.673076
# (Iteration 425 / 600) loss: 1.527674
# (Iteration 430 / 600) loss: 1.660686
# (Iteration 435 / 600) loss: 1.599167
# (Epoch 22 / 30) train acc: 0.381000; val_acc: 0.261000
# (Iteration 440 / 600) loss: 1.522655
# (Iteration 445 / 600) loss: 1.703670
# (Iteration 450 / 600) loss: 1.442865
# (Iteration 455 / 600) loss: 1.460193
# (Epoch 23 / 30) train acc: 0.364000; val_acc: 0.230000
# (Iteration 460 / 600) loss: 1.571911
# (Iteration 465 / 600) loss: 1.504740
# (Iteration 470 / 600) loss: 1.585927
# (Iteration 475 / 600) loss: 1.422055
# (Epoch 24 / 30) train acc: 0.394000; val_acc: 0.240000
# (Iteration 480 / 600) loss: 1.431615
# (Iteration 485 / 600) loss: 1.568630
# (Iteration 490 / 600) loss: 1.849922
# (Iteration 495 / 600) loss: 1.370979
# (Epoch 25 / 30) train acc: 0.404000; val_acc: 0.243000
# (Iteration 500 / 600) loss: 1.565240
# (Iteration 505 / 600) loss: 1.587592
# (Iteration 510 / 600) loss: 1.443588
# (Iteration 515 / 600) loss: 1.660714
# (Epoch 26 / 30) train acc: 0.425000; val_acc: 0.240000
# (Iteration 520 / 600) loss: 1.477601
# (Iteration 525 / 600) loss: 1.620166
# (Iteration 530 / 600) loss: 1.313588
# (Iteration 535 / 600) loss: 1.311268
# (Epoch 27 / 30) train acc: 0.425000; val_acc: 0.236000
# (Iteration 540 / 600) loss: 1.394727
# (Iteration 545 / 600) loss: 1.386622
# (Iteration 550 / 600) loss: 1.440265
# (Iteration 555 / 600) loss: 1.495029
# (Epoch 28 / 30) train acc: 0.428000; val_acc: 0.246000
# (Iteration 560 / 600) loss: 1.304909
# (Iteration 565 / 600) loss: 1.511093
# (Iteration 570 / 600) loss: 1.380495
# (Iteration 575 / 600) loss: 1.314068
# (Epoch 29 / 30) train acc: 0.441000; val_acc: 0.245000
# (Iteration 580 / 600) loss: 1.556660
# (Iteration 585 / 600) loss: 1.380043
# (Iteration 590 / 600) loss: 1.524606
# (Iteration 595 / 600) loss: 1.451268
# (Epoch 30 / 30) train acc: 0.457000; val_acc: 0.261000
#
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.102000; val_acc: 0.087000
# (Iteration 5 / 600) loss: 2.302708
# (Iteration 10 / 600) loss: 2.301876
# (Iteration 15 / 600) loss: 2.301308
# (Epoch 1 / 30) train acc: 0.102000; val_acc: 0.087000
# (Iteration 20 / 600) loss: 2.299307
# (Iteration 25 / 600) loss: 2.300943
# (Iteration 30 / 600) loss: 2.297170
# (Iteration 35 / 600) loss: 2.301441
# (Epoch 2 / 30) train acc: 0.102000; val_acc: 0.087000
# (Iteration 40 / 600) loss: 2.301204
# (Iteration 45 / 600) loss: 2.303780
# (Iteration 50 / 600) loss: 2.303816
# (Iteration 55 / 600) loss: 2.301205
# (Epoch 3 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 60 / 600) loss: 2.300578
# (Iteration 65 / 600) loss: 2.301473
# (Iteration 70 / 600) loss: 2.298651
# (Iteration 75 / 600) loss: 2.297420
# (Epoch 4 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 80 / 600) loss: 2.300531
# (Iteration 85 / 600) loss: 2.299476
# (Iteration 90 / 600) loss: 2.305514
# (Iteration 95 / 600) loss: 2.298132
# (Epoch 5 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 100 / 600) loss: 2.302693
# (Iteration 105 / 600) loss: 2.298389
# (Iteration 110 / 600) loss: 2.305822
# (Iteration 115 / 600) loss: 2.300041
# (Epoch 6 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 120 / 600) loss: 2.294596
# (Iteration 125 / 600) loss: 2.299294
# (Iteration 130 / 600) loss: 2.306979
# (Iteration 135 / 600) loss: 2.302240
# (Epoch 7 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 140 / 600) loss: 2.308043
# (Iteration 145 / 600) loss: 2.302217
# (Iteration 150 / 600) loss: 2.298918
# (Iteration 155 / 600) loss: 2.299653
# (Epoch 8 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 160 / 600) loss: 2.299099
# (Iteration 165 / 600) loss: 2.296684
# (Iteration 170 / 600) loss: 2.291035
# (Iteration 175 / 600) loss: 2.308737
# (Epoch 9 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 180 / 600) loss: 2.301609
# (Iteration 185 / 600) loss: 2.312782
# (Iteration 190 / 600) loss: 2.301064
# (Iteration 195 / 600) loss: 2.300122
# (Epoch 10 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 200 / 600) loss: 2.297153
# (Iteration 205 / 600) loss: 2.301321
# (Iteration 210 / 600) loss: 2.313324
# (Iteration 215 / 600) loss: 2.294958
# (Epoch 11 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 220 / 600) loss: 2.301583
# (Iteration 225 / 600) loss: 2.308368
# (Iteration 230 / 600) loss: 2.292028
# (Iteration 235 / 600) loss: 2.306458
# (Epoch 12 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 240 / 600) loss: 2.304472
# (Iteration 245 / 600) loss: 2.302835
# (Iteration 250 / 600) loss: 2.294202
# (Iteration 255 / 600) loss: 2.306693
# (Epoch 13 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 260 / 600) loss: 2.301906
# (Iteration 265 / 600) loss: 2.308008
# (Iteration 270 / 600) loss: 2.305409
# (Iteration 275 / 600) loss: 2.294558
# (Epoch 14 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 280 / 600) loss: 2.301149
# (Iteration 285 / 600) loss: 2.296638
# (Iteration 290 / 600) loss: 2.306889
# (Iteration 295 / 600) loss: 2.305053
# (Epoch 15 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 300 / 600) loss: 2.300500
# (Iteration 305 / 600) loss: 2.299806
# (Iteration 310 / 600) loss: 2.306770
# (Iteration 315 / 600) loss: 2.297949
# (Epoch 16 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 320 / 600) loss: 2.310066
# (Iteration 325 / 600) loss: 2.307881
# (Iteration 330 / 600) loss: 2.306425
# (Iteration 335 / 600) loss: 2.285260
# (Epoch 17 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 340 / 600) loss: 2.302640
# (Iteration 345 / 600) loss: 2.307880
# (Iteration 350 / 600) loss: 2.307678
# (Iteration 355 / 600) loss: 2.313716
# (Epoch 18 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 360 / 600) loss: 2.295450
# (Iteration 365 / 600) loss: 2.304378
# (Iteration 370 / 600) loss: 2.287025
# (Iteration 375 / 600) loss: 2.298908
# (Epoch 19 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 380 / 600) loss: 2.308205
# (Iteration 385 / 600) loss: 2.309507
# (Iteration 390 / 600) loss: 2.293682
# (Iteration 395 / 600) loss: 2.300559
# (Epoch 20 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 400 / 600) loss: 2.297460
# (Iteration 405 / 600) loss: 2.310118
# (Iteration 410 / 600) loss: 2.283700
# (Iteration 415 / 600) loss: 2.295767
# (Epoch 21 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 420 / 600) loss: 2.305732
# (Iteration 425 / 600) loss: 2.298450
# (Iteration 430 / 600) loss: 2.294207
# (Iteration 435 / 600) loss: 2.317059
# (Epoch 22 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 440 / 600) loss: 2.280480
# (Iteration 445 / 600) loss: 2.316197
# (Iteration 450 / 600) loss: 2.291940
# (Iteration 455 / 600) loss: 2.290295
# (Epoch 23 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 460 / 600) loss: 2.305172
# (Iteration 465 / 600) loss: 2.301180
# (Iteration 470 / 600) loss: 2.298053
# (Iteration 475 / 600) loss: 2.289462
# (Epoch 24 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 480 / 600) loss: 2.293035
# (Iteration 485 / 600) loss: 2.294353
# (Iteration 490 / 600) loss: 2.289778
# (Iteration 495 / 600) loss: 2.309775
# (Epoch 25 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 500 / 600) loss: 2.308255
# (Iteration 505 / 600) loss: 2.309557
# (Iteration 510 / 600) loss: 2.304083
# (Iteration 515 / 600) loss: 2.313892
# (Epoch 26 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 520 / 600) loss: 2.300063
# (Iteration 525 / 600) loss: 2.302838
# (Iteration 530 / 600) loss: 2.295181
# (Iteration 535 / 600) loss: 2.304866
# (Epoch 27 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 540 / 600) loss: 2.300222
# (Iteration 545 / 600) loss: 2.296853
# (Iteration 550 / 600) loss: 2.296926
# (Iteration 555 / 600) loss: 2.307042
# (Epoch 28 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 560 / 600) loss: 2.306027
# (Iteration 565 / 600) loss: 2.291142
# (Iteration 570 / 600) loss: 2.302055
# (Iteration 575 / 600) loss: 2.326738
# (Epoch 29 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 580 / 600) loss: 2.294276
# (Iteration 585 / 600) loss: 2.317633
# (Iteration 590 / 600) loss: 2.289705
# (Iteration 595 / 600) loss: 2.306715
# (Epoch 30 / 30) train acc: 0.112000; val_acc: 0.119000
#
# Running weight scale 3 / 20
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.099000; val_acc: 0.078000
# (Iteration 5 / 600) loss: 2.300088
# (Iteration 10 / 600) loss: 2.256557
# (Iteration 15 / 600) loss: 2.282195
# (Epoch 1 / 30) train acc: 0.170000; val_acc: 0.153000
# (Iteration 20 / 600) loss: 2.145727
# (Iteration 25 / 600) loss: 2.147994
# (Iteration 30 / 600) loss: 2.086403
# (Iteration 35 / 600) loss: 2.132327
# (Epoch 2 / 30) train acc: 0.188000; val_acc: 0.159000
# (Iteration 40 / 600) loss: 2.129508
# (Iteration 45 / 600) loss: 1.925598
# (Iteration 50 / 600) loss: 1.915600
# (Iteration 55 / 600) loss: 2.074635
# (Epoch 3 / 30) train acc: 0.218000; val_acc: 0.213000
# (Iteration 60 / 600) loss: 1.869780
# (Iteration 65 / 600) loss: 2.054145
# (Iteration 70 / 600) loss: 1.831967
# (Iteration 75 / 600) loss: 1.907256
# (Epoch 4 / 30) train acc: 0.250000; val_acc: 0.225000
# (Iteration 80 / 600) loss: 1.838989
# (Iteration 85 / 600) loss: 1.907317
# (Iteration 90 / 600) loss: 1.873267
# (Iteration 95 / 600) loss: 1.908757
# (Epoch 5 / 30) train acc: 0.235000; val_acc: 0.220000
# (Iteration 100 / 600) loss: 1.814169
# (Iteration 105 / 600) loss: 1.980324
# (Iteration 110 / 600) loss: 1.874913
# (Iteration 115 / 600) loss: 1.862685
# (Epoch 6 / 30) train acc: 0.282000; val_acc: 0.223000
# (Iteration 120 / 600) loss: 1.774895
# (Iteration 125 / 600) loss: 1.779851
# (Iteration 130 / 600) loss: 1.888405
# (Iteration 135 / 600) loss: 1.823733
# (Epoch 7 / 30) train acc: 0.290000; val_acc: 0.223000
# (Iteration 140 / 600) loss: 1.816024
# (Iteration 145 / 600) loss: 1.793276
# (Iteration 150 / 600) loss: 1.784089
# (Iteration 155 / 600) loss: 1.718094
# (Epoch 8 / 30) train acc: 0.269000; val_acc: 0.243000
# (Iteration 160 / 600) loss: 1.815729
# (Iteration 165 / 600) loss: 1.984167
# (Iteration 170 / 600) loss: 1.628233
# (Iteration 175 / 600) loss: 1.797286
# (Epoch 9 / 30) train acc: 0.301000; val_acc: 0.211000
# (Iteration 180 / 600) loss: 1.953778
# (Iteration 185 / 600) loss: 1.745929
# (Iteration 190 / 600) loss: 1.682557
# (Iteration 195 / 600) loss: 1.787584
# (Epoch 10 / 30) train acc: 0.320000; val_acc: 0.218000
# (Iteration 200 / 600) loss: 1.563242
# (Iteration 205 / 600) loss: 1.617714
# (Iteration 210 / 600) loss: 1.766736
# (Iteration 215 / 600) loss: 1.650230
# (Epoch 11 / 30) train acc: 0.335000; val_acc: 0.236000
# (Iteration 220 / 600) loss: 1.611859
# (Iteration 225 / 600) loss: 1.572930
# (Iteration 230 / 600) loss: 1.724048
# (Iteration 235 / 600) loss: 1.575575
# (Epoch 12 / 30) train acc: 0.360000; val_acc: 0.233000
# (Iteration 240 / 600) loss: 1.551595
# (Iteration 245 / 600) loss: 1.424645
# (Iteration 250 / 600) loss: 1.548614
# (Iteration 255 / 600) loss: 1.594235
# (Epoch 13 / 30) train acc: 0.364000; val_acc: 0.215000
# (Iteration 260 / 600) loss: 1.559840
# (Iteration 265 / 600) loss: 1.469764
# (Iteration 270 / 600) loss: 1.591728
# (Iteration 275 / 600) loss: 1.490446
# (Epoch 14 / 30) train acc: 0.380000; val_acc: 0.232000
# (Iteration 280 / 600) loss: 1.487188
# (Iteration 285 / 600) loss: 1.769628
# (Iteration 290 / 600) loss: 1.413490
# (Iteration 295 / 600) loss: 1.475067
# (Epoch 15 / 30) train acc: 0.391000; val_acc: 0.245000
# (Iteration 300 / 600) loss: 1.373565
# (Iteration 305 / 600) loss: 1.592931
# (Iteration 310 / 600) loss: 1.564022
# (Iteration 315 / 600) loss: 1.442663
# (Epoch 16 / 30) train acc: 0.404000; val_acc: 0.246000
# (Iteration 320 / 600) loss: 1.476944
# (Iteration 325 / 600) loss: 1.329632
# (Iteration 330 / 600) loss: 1.413601
# (Iteration 335 / 600) loss: 1.394931
# (Epoch 17 / 30) train acc: 0.420000; val_acc: 0.261000
# (Iteration 340 / 600) loss: 1.345609
# (Iteration 345 / 600) loss: 1.420397
# (Iteration 350 / 600) loss: 1.374350
# (Iteration 355 / 600) loss: 1.360710
# (Epoch 18 / 30) train acc: 0.429000; val_acc: 0.253000
# (Iteration 360 / 600) loss: 1.316228
# (Iteration 365 / 600) loss: 1.208665
# (Iteration 370 / 600) loss: 1.261555
# (Iteration 375 / 600) loss: 1.352968
# (Epoch 19 / 30) train acc: 0.444000; val_acc: 0.239000
# (Iteration 380 / 600) loss: 1.421795
# (Iteration 385 / 600) loss: 1.434409
# (Iteration 390 / 600) loss: 1.332762
# (Iteration 395 / 600) loss: 1.311191
# (Epoch 20 / 30) train acc: 0.453000; val_acc: 0.246000
# (Iteration 400 / 600) loss: 1.175622
# (Iteration 405 / 600) loss: 1.317171
# (Iteration 410 / 600) loss: 1.374654
# (Iteration 415 / 600) loss: 1.458662
# (Epoch 21 / 30) train acc: 0.481000; val_acc: 0.227000
# (Iteration 420 / 600) loss: 1.313495
# (Iteration 425 / 600) loss: 1.363731
# (Iteration 430 / 600) loss: 1.191253
# (Iteration 435 / 600) loss: 1.181342
# (Epoch 22 / 30) train acc: 0.502000; val_acc: 0.246000
# (Iteration 440 / 600) loss: 1.198127
# (Iteration 445 / 600) loss: 1.314486
# (Iteration 450 / 600) loss: 1.298418
# (Iteration 455 / 600) loss: 1.243651
# (Epoch 23 / 30) train acc: 0.501000; val_acc: 0.243000
# (Iteration 460 / 600) loss: 1.252507
# (Iteration 465 / 600) loss: 1.098283
# (Iteration 470 / 600) loss: 1.068210
# (Iteration 475 / 600) loss: 1.220643
# (Epoch 24 / 30) train acc: 0.506000; val_acc: 0.243000
# (Iteration 480 / 600) loss: 1.026277
# (Iteration 485 / 600) loss: 1.124910
# (Iteration 490 / 600) loss: 1.395396
# (Iteration 495 / 600) loss: 1.157077
# (Epoch 25 / 30) train acc: 0.521000; val_acc: 0.246000
# (Iteration 500 / 600) loss: 1.025619
# (Iteration 505 / 600) loss: 0.985675
# (Iteration 510 / 600) loss: 1.241799
# (Iteration 515 / 600) loss: 1.066221
# (Epoch 26 / 30) train acc: 0.543000; val_acc: 0.250000
# (Iteration 520 / 600) loss: 1.167315
# (Iteration 525 / 600) loss: 1.363582
# (Iteration 530 / 600) loss: 1.260773
# (Iteration 535 / 600) loss: 1.070525
# (Epoch 27 / 30) train acc: 0.554000; val_acc: 0.261000
# (Iteration 540 / 600) loss: 1.143039
# (Iteration 545 / 600) loss: 1.187725
# (Iteration 550 / 600) loss: 0.993284
# (Iteration 555 / 600) loss: 1.019393
# (Epoch 28 / 30) train acc: 0.562000; val_acc: 0.261000
# (Iteration 560 / 600) loss: 1.040415
# (Iteration 565 / 600) loss: 1.033953
# (Iteration 570 / 600) loss: 0.969299
# (Iteration 575 / 600) loss: 1.145914
# (Epoch 29 / 30) train acc: 0.570000; val_acc: 0.243000
# (Iteration 580 / 600) loss: 1.066000
# (Iteration 585 / 600) loss: 1.009745
# (Iteration 590 / 600) loss: 0.910821
# (Iteration 595 / 600) loss: 1.128282
# (Epoch 30 / 30) train acc: 0.582000; val_acc: 0.223000
#
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.102000; val_acc: 0.087000
# (Iteration 5 / 600) loss: 2.302151
# (Iteration 10 / 600) loss: 2.300850
# (Iteration 15 / 600) loss: 2.300615
# (Epoch 1 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 20 / 600) loss: 2.303399
# (Iteration 25 / 600) loss: 2.302784
# (Iteration 30 / 600) loss: 2.296603
# (Iteration 35 / 600) loss: 2.301727
# (Epoch 2 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 40 / 600) loss: 2.295390
# (Iteration 45 / 600) loss: 2.301787
# (Iteration 50 / 600) loss: 2.303821
# (Iteration 55 / 600) loss: 2.305485
# (Epoch 3 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 60 / 600) loss: 2.298042
# (Iteration 65 / 600) loss: 2.299857
# (Iteration 70 / 600) loss: 2.297655
# (Iteration 75 / 600) loss: 2.303141
# (Epoch 4 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 80 / 600) loss: 2.300276
# (Iteration 85 / 600) loss: 2.296688
# (Iteration 90 / 600) loss: 2.292401
# (Iteration 95 / 600) loss: 2.302328
# (Epoch 5 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 100 / 600) loss: 2.299182
# (Iteration 105 / 600) loss: 2.298618
# (Iteration 110 / 600) loss: 2.293828
# (Iteration 115 / 600) loss: 2.305072
# (Epoch 6 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 120 / 600) loss: 2.303434
# (Iteration 125 / 600) loss: 2.303366
# (Iteration 130 / 600) loss: 2.301854
# (Iteration 135 / 600) loss: 2.301048
# (Epoch 7 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 140 / 600) loss: 2.306467
# (Iteration 145 / 600) loss: 2.295554
# (Iteration 150 / 600) loss: 2.300829
# (Iteration 155 / 600) loss: 2.289256
# (Epoch 8 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 160 / 600) loss: 2.304190
# (Iteration 165 / 600) loss: 2.306629
# (Iteration 170 / 600) loss: 2.309732
# (Iteration 175 / 600) loss: 2.301426
# (Epoch 9 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 180 / 600) loss: 2.303287
# (Iteration 185 / 600) loss: 2.294250
# (Iteration 190 / 600) loss: 2.306693
# (Iteration 195 / 600) loss: 2.292613
# (Epoch 10 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 200 / 600) loss: 2.306923
# (Iteration 205 / 600) loss: 2.303498
# (Iteration 210 / 600) loss: 2.313101
# (Iteration 215 / 600) loss: 2.301466
# (Epoch 11 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 220 / 600) loss: 2.297080
# (Iteration 225 / 600) loss: 2.304147
# (Iteration 230 / 600) loss: 2.288166
# (Iteration 235 / 600) loss: 2.309206
# (Epoch 12 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 240 / 600) loss: 2.292194
# (Iteration 245 / 600) loss: 2.304854
# (Iteration 250 / 600) loss: 2.313293
# (Iteration 255 / 600) loss: 2.295347
# (Epoch 13 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 260 / 600) loss: 2.300907
# (Iteration 265 / 600) loss: 2.301551
# (Iteration 270 / 600) loss: 2.301144
# (Iteration 275 / 600) loss: 2.295692
# (Epoch 14 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 280 / 600) loss: 2.292825
# (Iteration 285 / 600) loss: 2.303304
# (Iteration 290 / 600) loss: 2.292486
# (Iteration 295 / 600) loss: 2.305119
# (Epoch 15 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 300 / 600) loss: 2.301048
# (Iteration 305 / 600) loss: 2.309750
# (Iteration 310 / 600) loss: 2.299638
# (Iteration 315 / 600) loss: 2.298261
# (Epoch 16 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 320 / 600) loss: 2.301757
# (Iteration 325 / 600) loss: 2.303201
# (Iteration 330 / 600) loss: 2.300582
# (Iteration 335 / 600) loss: 2.292859
# (Epoch 17 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 340 / 600) loss: 2.298332
# (Iteration 345 / 600) loss: 2.296787
# (Iteration 350 / 600) loss: 2.311711
# (Iteration 355 / 600) loss: 2.308753
# (Epoch 18 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 360 / 600) loss: 2.298448
# (Iteration 365 / 600) loss: 2.298649
# (Iteration 370 / 600) loss: 2.302211
# (Iteration 375 / 600) loss: 2.300975
# (Epoch 19 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 380 / 600) loss: 2.310996
# (Iteration 385 / 600) loss: 2.296992
# (Iteration 390 / 600) loss: 2.314147
# (Iteration 395 / 600) loss: 2.297809
# (Epoch 20 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 400 / 600) loss: 2.292640
# (Iteration 405 / 600) loss: 2.306667
# (Iteration 410 / 600) loss: 2.299431
# (Iteration 415 / 600) loss: 2.288967
# (Epoch 21 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 420 / 600) loss: 2.301523
# (Iteration 425 / 600) loss: 2.294604
# (Iteration 430 / 600) loss: 2.306678
# (Iteration 435 / 600) loss: 2.304658
# (Epoch 22 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 440 / 600) loss: 2.309446
# (Iteration 445 / 600) loss: 2.297266
# (Iteration 450 / 600) loss: 2.306532
# (Iteration 455 / 600) loss: 2.304776
# (Epoch 23 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 460 / 600) loss: 2.296723
# (Iteration 465 / 600) loss: 2.310113
# (Iteration 470 / 600) loss: 2.300403
# (Iteration 475 / 600) loss: 2.293479
# (Epoch 24 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 480 / 600) loss: 2.295263
# (Iteration 485 / 600) loss: 2.313042
# (Iteration 490 / 600) loss: 2.291035
# (Iteration 495 / 600) loss: 2.301001
# (Epoch 25 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 500 / 600) loss: 2.304075
# (Iteration 505 / 600) loss: 2.291300
# (Iteration 510 / 600) loss: 2.310629
# (Iteration 515 / 600) loss: 2.298753
# (Epoch 26 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 520 / 600) loss: 2.293669
# (Iteration 525 / 600) loss: 2.303736
# (Iteration 530 / 600) loss: 2.296441
# (Iteration 535 / 600) loss: 2.305030
# (Epoch 27 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 540 / 600) loss: 2.302303
# (Iteration 545 / 600) loss: 2.304884
# (Iteration 550 / 600) loss: 2.286124
# (Iteration 555 / 600) loss: 2.291198
# (Epoch 28 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 560 / 600) loss: 2.305335
# (Iteration 565 / 600) loss: 2.295846
# (Iteration 570 / 600) loss: 2.302742
# (Iteration 575 / 600) loss: 2.304975
# (Epoch 29 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 580 / 600) loss: 2.300745
# (Iteration 585 / 600) loss: 2.317020
# (Iteration 590 / 600) loss: 2.303655
# (Iteration 595 / 600) loss: 2.296908
# (Epoch 30 / 30) train acc: 0.112000; val_acc: 0.119000
#
# Running weight scale 4 / 20
# (Iteration 0 / 600) loss: 2.302593
# (Epoch 0 / 30) train acc: 0.090000; val_acc: 0.105000
# (Iteration 5 / 600) loss: 2.311301
# (Iteration 10 / 600) loss: 2.241826
# (Iteration 15 / 600) loss: 2.240987
# (Epoch 1 / 30) train acc: 0.202000; val_acc: 0.172000
# (Iteration 20 / 600) loss: 2.140388
# (Iteration 25 / 600) loss: 2.125726
# (Iteration 30 / 600) loss: 2.131860
# (Iteration 35 / 600) loss: 1.982289
# (Epoch 2 / 30) train acc: 0.228000; val_acc: 0.202000
# (Iteration 40 / 600) loss: 2.252149
# (Iteration 45 / 600) loss: 1.904929
# (Iteration 50 / 600) loss: 1.851650
# (Iteration 55 / 600) loss: 1.945501
# (Epoch 3 / 30) train acc: 0.234000; val_acc: 0.209000
# (Iteration 60 / 600) loss: 2.065916
# (Iteration 65 / 600) loss: 1.857219
# (Iteration 70 / 600) loss: 1.893961
# (Iteration 75 / 600) loss: 2.057770
# (Epoch 4 / 30) train acc: 0.269000; val_acc: 0.239000
# (Iteration 80 / 600) loss: 1.895824
# (Iteration 85 / 600) loss: 2.140289
# (Iteration 90 / 600) loss: 1.843964
# (Iteration 95 / 600) loss: 1.813014
# (Epoch 5 / 30) train acc: 0.273000; val_acc: 0.240000
# (Iteration 100 / 600) loss: 1.818431
# (Iteration 105 / 600) loss: 1.823476
# (Iteration 110 / 600) loss: 1.777981
# (Iteration 115 / 600) loss: 1.679555
# (Epoch 6 / 30) train acc: 0.322000; val_acc: 0.250000
# (Iteration 120 / 600) loss: 1.822345
# (Iteration 125 / 600) loss: 1.684444
# (Iteration 130 / 600) loss: 1.874396
# (Iteration 135 / 600) loss: 1.736662
# (Epoch 7 / 30) train acc: 0.335000; val_acc: 0.264000
# (Iteration 140 / 600) loss: 1.703743
# (Iteration 145 / 600) loss: 1.923417
# (Iteration 150 / 600) loss: 1.720894
# (Iteration 155 / 600) loss: 1.812332
# (Epoch 8 / 30) train acc: 0.326000; val_acc: 0.248000
# (Iteration 160 / 600) loss: 1.737935
# (Iteration 165 / 600) loss: 1.854817
# (Iteration 170 / 600) loss: 1.647440
# (Iteration 175 / 600) loss: 1.759672
# (Epoch 9 / 30) train acc: 0.355000; val_acc: 0.270000
# (Iteration 180 / 600) loss: 1.794944
# (Iteration 185 / 600) loss: 1.754072
# (Iteration 190 / 600) loss: 1.511958
# (Iteration 195 / 600) loss: 1.746733
# (Epoch 10 / 30) train acc: 0.383000; val_acc: 0.251000
# (Iteration 200 / 600) loss: 1.479032
# (Iteration 205 / 600) loss: 1.604469
# (Iteration 210 / 600) loss: 1.484166
# (Iteration 215 / 600) loss: 1.600340
# (Epoch 11 / 30) train acc: 0.407000; val_acc: 0.266000
# (Iteration 220 / 600) loss: 1.483832
# (Iteration 225 / 600) loss: 1.419654
# (Iteration 230 / 600) loss: 1.494372
# (Iteration 235 / 600) loss: 1.495063
# (Epoch 12 / 30) train acc: 0.414000; val_acc: 0.259000
# (Iteration 240 / 600) loss: 1.548575
# (Iteration 245 / 600) loss: 1.657463
# (Iteration 250 / 600) loss: 1.715304
# (Iteration 255 / 600) loss: 1.514190
# (Epoch 13 / 30) train acc: 0.424000; val_acc: 0.265000
# (Iteration 260 / 600) loss: 1.376803
# (Iteration 265 / 600) loss: 1.560602
# (Iteration 270 / 600) loss: 1.359538
# (Iteration 275 / 600) loss: 1.308411
# (Epoch 14 / 30) train acc: 0.427000; val_acc: 0.285000
# (Iteration 280 / 600) loss: 1.401817
# (Iteration 285 / 600) loss: 1.301019
# (Iteration 290 / 600) loss: 1.297816
# (Iteration 295 / 600) loss: 1.338437
# (Epoch 15 / 30) train acc: 0.448000; val_acc: 0.270000
# (Iteration 300 / 600) loss: 1.508581
# (Iteration 305 / 600) loss: 1.493584
# (Iteration 310 / 600) loss: 1.471993
# (Iteration 315 / 600) loss: 1.188823
# (Epoch 16 / 30) train acc: 0.447000; val_acc: 0.288000
# (Iteration 320 / 600) loss: 1.476900
# (Iteration 325 / 600) loss: 1.386952
# (Iteration 330 / 600) loss: 1.421317
# (Iteration 335 / 600) loss: 1.348484
# (Epoch 17 / 30) train acc: 0.474000; val_acc: 0.271000
# (Iteration 340 / 600) loss: 1.312735
# (Iteration 345 / 600) loss: 1.665319
# (Iteration 350 / 600) loss: 1.524093
# (Iteration 355 / 600) loss: 1.174375
# (Epoch 18 / 30) train acc: 0.478000; val_acc: 0.263000
# (Iteration 360 / 600) loss: 1.129135
# (Iteration 365 / 600) loss: 1.254898
# (Iteration 370 / 600) loss: 1.465113
# (Iteration 375 / 600) loss: 1.523259
# (Epoch 19 / 30) train acc: 0.496000; val_acc: 0.276000
# (Iteration 380 / 600) loss: 1.143065
# (Iteration 385 / 600) loss: 1.203451
# (Iteration 390 / 600) loss: 1.097568
# (Iteration 395 / 600) loss: 1.124473
# (Epoch 20 / 30) train acc: 0.492000; val_acc: 0.281000
# (Iteration 400 / 600) loss: 1.310492
# (Iteration 405 / 600) loss: 1.079589
# (Iteration 410 / 600) loss: 1.176895
# (Iteration 415 / 600) loss: 1.279256
# (Epoch 21 / 30) train acc: 0.480000; val_acc: 0.263000
# (Iteration 420 / 600) loss: 1.310604
# (Iteration 425 / 600) loss: 1.222253
# (Iteration 430 / 600) loss: 1.021162
# (Iteration 435 / 600) loss: 1.174815
# (Epoch 22 / 30) train acc: 0.535000; val_acc: 0.280000
# (Iteration 440 / 600) loss: 1.069455
# (Iteration 445 / 600) loss: 1.093645
# (Iteration 450 / 600) loss: 1.136279
# (Iteration 455 / 600) loss: 1.095248
# (Epoch 23 / 30) train acc: 0.526000; val_acc: 0.280000
# (Iteration 460 / 600) loss: 1.322512
# (Iteration 465 / 600) loss: 1.296062
# (Iteration 470 / 600) loss: 1.150926
# (Iteration 475 / 600) loss: 1.111467
# (Epoch 24 / 30) train acc: 0.559000; val_acc: 0.274000
# (Iteration 480 / 600) loss: 1.205304
# (Iteration 485 / 600) loss: 1.126119
# (Iteration 490 / 600) loss: 1.113089
# (Iteration 495 / 600) loss: 1.152027
# (Epoch 25 / 30) train acc: 0.520000; val_acc: 0.254000
# (Iteration 500 / 600) loss: 1.039315
# (Iteration 505 / 600) loss: 1.102496
# (Iteration 510 / 600) loss: 0.993398
# (Iteration 515 / 600) loss: 1.389945
# (Epoch 26 / 30) train acc: 0.571000; val_acc: 0.276000
# (Iteration 520 / 600) loss: 0.968313
# (Iteration 525 / 600) loss: 1.087089
# (Iteration 530 / 600) loss: 1.075644
# (Iteration 535 / 600) loss: 1.209585
# (Epoch 27 / 30) train acc: 0.597000; val_acc: 0.265000
# (Iteration 540 / 600) loss: 0.974849
# (Iteration 545 / 600) loss: 1.143828
# (Iteration 550 / 600) loss: 0.927373
# (Iteration 555 / 600) loss: 1.054058
# (Epoch 28 / 30) train acc: 0.601000; val_acc: 0.282000
# (Iteration 560 / 600) loss: 1.150903
# (Iteration 565 / 600) loss: 1.136480
# (Iteration 570 / 600) loss: 0.883666
# (Iteration 575 / 600) loss: 0.872790
# (Epoch 29 / 30) train acc: 0.630000; val_acc: 0.282000
# (Iteration 580 / 600) loss: 0.933045
# (Iteration 585 / 600) loss: 1.057710
# (Iteration 590 / 600) loss: 1.040997
# (Iteration 595 / 600) loss: 1.090141
# (Epoch 30 / 30) train acc: 0.618000; val_acc: 0.279000
#
# (Iteration 0 / 600) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 5 / 600) loss: 2.302248
# (Iteration 10 / 600) loss: 2.302659
# (Iteration 15 / 600) loss: 2.304250
# (Epoch 1 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 20 / 600) loss: 2.301176
# (Iteration 25 / 600) loss: 2.301312
# (Iteration 30 / 600) loss: 2.302870
# (Iteration 35 / 600) loss: 2.303832
# (Epoch 2 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 40 / 600) loss: 2.303795
# (Iteration 45 / 600) loss: 2.301774
# (Iteration 50 / 600) loss: 2.298579
# (Iteration 55 / 600) loss: 2.297880
# (Epoch 3 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 60 / 600) loss: 2.297588
# (Iteration 65 / 600) loss: 2.302228
# (Iteration 70 / 600) loss: 2.301804
# (Iteration 75 / 600) loss: 2.299596
# (Epoch 4 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 80 / 600) loss: 2.299368
# (Iteration 85 / 600) loss: 2.301950
# (Iteration 90 / 600) loss: 2.291990
# (Iteration 95 / 600) loss: 2.295841
# (Epoch 5 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 100 / 600) loss: 2.296494
# (Iteration 105 / 600) loss: 2.305790
# (Iteration 110 / 600) loss: 2.309074
# (Iteration 115 / 600) loss: 2.300127
# (Epoch 6 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 120 / 600) loss: 2.294335
# (Iteration 125 / 600) loss: 2.301815
# (Iteration 130 / 600) loss: 2.290598
# (Iteration 135 / 600) loss: 2.306712
# (Epoch 7 / 30) train acc: 0.107000; val_acc: 0.102000
# (Iteration 140 / 600) loss: 2.310883
# (Iteration 145 / 600) loss: 2.284304
# (Iteration 150 / 600) loss: 2.291009
# (Iteration 155 / 600) loss: 2.307615
# (Epoch 8 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 160 / 600) loss: 2.312144
# (Iteration 165 / 600) loss: 2.299995
# (Iteration 170 / 600) loss: 2.303431
# (Iteration 175 / 600) loss: 2.310120
# (Epoch 9 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 180 / 600) loss: 2.307495
# (Iteration 185 / 600) loss: 2.299644
# (Iteration 190 / 600) loss: 2.301519
# (Iteration 195 / 600) loss: 2.322567
# (Epoch 10 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 200 / 600) loss: 2.303887
# (Iteration 205 / 600) loss: 2.289037
# (Iteration 210 / 600) loss: 2.305988
# (Iteration 215 / 600) loss: 2.303572
# (Epoch 11 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 220 / 600) loss: 2.303733
# (Iteration 225 / 600) loss: 2.298524
# (Iteration 230 / 600) loss: 2.297761
# (Iteration 235 / 600) loss: 2.306771
# (Epoch 12 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 240 / 600) loss: 2.302289
# (Iteration 245 / 600) loss: 2.310895
# (Iteration 250 / 600) loss: 2.302074
# (Iteration 255 / 600) loss: 2.310074
# (Epoch 13 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 260 / 600) loss: 2.304767
# (Iteration 265 / 600) loss: 2.313912
# (Iteration 270 / 600) loss: 2.286673
# (Iteration 275 / 600) loss: 2.301500
# (Epoch 14 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 280 / 600) loss: 2.296489
# (Iteration 285 / 600) loss: 2.303416
# (Iteration 290 / 600) loss: 2.299167
# (Iteration 295 / 600) loss: 2.308796
# (Epoch 15 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 300 / 600) loss: 2.303065
# (Iteration 305 / 600) loss: 2.296284
# (Iteration 310 / 600) loss: 2.299675
# (Iteration 315 / 600) loss: 2.308898
# (Epoch 16 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 320 / 600) loss: 2.298698
# (Iteration 325 / 600) loss: 2.324984
# (Iteration 330 / 600) loss: 2.291785
# (Iteration 335 / 600) loss: 2.298488
# (Epoch 17 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 340 / 600) loss: 2.299581
# (Iteration 345 / 600) loss: 2.301711
# (Iteration 350 / 600) loss: 2.294517
# (Iteration 355 / 600) loss: 2.303526
# (Epoch 18 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 360 / 600) loss: 2.306180
# (Iteration 365 / 600) loss: 2.293317
# (Iteration 370 / 600) loss: 2.306029
# (Iteration 375 / 600) loss: 2.297406
# (Epoch 19 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 380 / 600) loss: 2.305611
# (Iteration 385 / 600) loss: 2.309743
# (Iteration 390 / 600) loss: 2.285024
# (Iteration 395 / 600) loss: 2.292192
# (Epoch 20 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 400 / 600) loss: 2.311206
# (Iteration 405 / 600) loss: 2.294856
# (Iteration 410 / 600) loss: 2.293570
# (Iteration 415 / 600) loss: 2.299882
# (Epoch 21 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 420 / 600) loss: 2.277326
# (Iteration 425 / 600) loss: 2.305893
# (Iteration 430 / 600) loss: 2.290885
# (Iteration 435 / 600) loss: 2.316162
# (Epoch 22 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 440 / 600) loss: 2.293714
# (Iteration 445 / 600) loss: 2.285723
# (Iteration 450 / 600) loss: 2.297193
# (Iteration 455 / 600) loss: 2.290139
# (Epoch 23 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 460 / 600) loss: 2.300315
# (Iteration 465 / 600) loss: 2.293585
# (Iteration 470 / 600) loss: 2.309457
# (Iteration 475 / 600) loss: 2.292120
# (Epoch 24 / 30) train acc: 0.112000; val_acc: 0.119000
# (Iteration 480 / 600) loss: 2.310672
# (Iteration 485 / 600) loss: 2.292803
# (Iteration 490 / 600) loss: 2.305858
# (Iteration 495 / 600) loss: 2.326309
# ...
# (Iteration 330 / 600) loss: 49264.520000
# (Iteration 335 / 600) loss: 39433.477500
# (Epoch 17 / 30) train acc: 0.707000; val_acc: 0.136000
# (Iteration 340 / 600) loss: 46975.825000
# (Iteration 345 / 600) loss: 73188.490000
# (Iteration 350 / 600) loss: 61821.150000
# (Iteration 355 / 600) loss: 66573.880000
# (Epoch 18 / 30) train acc: 0.711000; val_acc: 0.137000
# (Iteration 360 / 600) loss: 45401.410000
# (Iteration 365 / 600) loss: 34870.622500
# (Iteration 370 / 600) loss: 76123.850000
# (Iteration 375 / 600) loss: 38451.337500
# (Epoch 19 / 30) train acc: 0.731000; val_acc: 0.133000
# (Iteration 380 / 600) loss: 34090.450000
# (Iteration 385 / 600) loss: 45730.370000
# (Iteration 390 / 600) loss: 69943.430000
# (Iteration 395 / 600) loss: 27532.650000
# (Epoch 20 / 30) train acc: 0.732000; val_acc: 0.131000
# (Iteration 400 / 600) loss: 44311.635000
# (Iteration 405 / 600) loss: 24523.085000
# (Iteration 410 / 600) loss: 20542.296250
# (Iteration 415 / 600) loss: 42334.555000
# (Epoch 21 / 30) train acc: 0.752000; val_acc: 0.140000
# (Iteration 420 / 600) loss: 39905.630000
# (Iteration 425 / 600) loss: 46632.430000
# (Iteration 430 / 600) loss: 19070.773750
# (Iteration 435 / 600) loss: 36416.405000
# (Epoch 22 / 30) train acc: 0.762000; val_acc: 0.135000
# (Iteration 440 / 600) loss: 15714.815000
# (Iteration 445 / 600) loss: 33999.027500
# (Iteration 450 / 600) loss: 20381.763750
# (Iteration 455 / 600) loss: 65440.195000
# (Epoch 23 / 30) train acc: 0.754000; val_acc: 0.139000
# (Iteration 460 / 600) loss: 11457.903750
# (Iteration 465 / 600) loss: 11570.883750
# (Iteration 470 / 600) loss: 58478.445000
# (Iteration 475 / 600) loss: 19009.621250
# (Epoch 24 / 30) train acc: 0.772000; val_acc: 0.141000
# (Iteration 480 / 600) loss: 22279.265000
# (Iteration 485 / 600) loss: 15626.727500
# (Iteration 490 / 600) loss: 45757.860000
# (Iteration 495 / 600) loss: 22797.030000
# (Epoch 25 / 30) train acc: 0.781000; val_acc: 0.138000
# (Iteration 500 / 600) loss: 52850.960000
# (Iteration 505 / 600) loss: 65388.735000
# (Iteration 510 / 600) loss: 28912.730000
# (Iteration 515 / 600) loss: 8626.385000
# (Epoch 26 / 30) train acc: 0.796000; val_acc: 0.137000
# (Iteration 520 / 600) loss: 13503.987500
# (Iteration 525 / 600) loss: 28179.052500
# (Iteration 530 / 600) loss: 19291.782500
# (Iteration 535 / 600) loss: 28613.615000
# (Epoch 27 / 30) train acc: 0.800000; val_acc: 0.139000
# (Iteration 540 / 600) loss: 25971.970000
# (Iteration 545 / 600) loss: 15375.176250
# (Iteration 550 / 600) loss: 24709.855000
# (Iteration 555 / 600) loss: 6524.831250
# (Epoch 28 / 30) train acc: 0.817000; val_acc: 0.146000
# (Iteration 560 / 600) loss: 21588.347500
# (Iteration 565 / 600) loss: 24817.505000
# (Iteration 570 / 600) loss: 14714.836250
# (Iteration 575 / 600) loss: 52567.105000
# (Epoch 29 / 30) train acc: 0.834000; val_acc: 0.143000
# (Iteration 580 / 600) loss: 3255.122500
# (Iteration 585 / 600) loss: 14151.831250
# (Iteration 590 / 600) loss: 7618.203750
# (Iteration 595 / 600) loss: 11145.222500
# (Epoch 30 / 30) train acc: 0.836000; val_acc: 0.143000
#
# Running weight scale 20 / 20
# (Iteration 0 / 600) loss: 9.329838
# (Epoch 0 / 30) train acc: 0.110000; val_acc: 0.118000
# (Iteration 5 / 600) loss: 8.874860
# (Iteration 10 / 600) loss: 7.714233
# (Iteration 15 / 600) loss: 7.035574
# (Epoch 1 / 30) train acc: 0.123000; val_acc: 0.104000
# (Iteration 20 / 600) loss: 7.470629
# (Iteration 25 / 600) loss: 6.605483
# (Iteration 30 / 600) loss: 7.079259
# (Iteration 35 / 600) loss: 5.108222
# (Epoch 2 / 30) train acc: 0.152000; val_acc: 0.107000
# (Iteration 40 / 600) loss: 6.032231
# (Iteration 45 / 600) loss: 4.768344
# (Iteration 50 / 600) loss: 4.782840
# (Iteration 55 / 600) loss: 3.896964
# (Epoch 3 / 30) train acc: 0.187000; val_acc: 0.123000
# (Iteration 60 / 600) loss: 4.642460
# (Iteration 65 / 600) loss: 4.053483
# (Iteration 70 / 600) loss: 3.568187
# (Iteration 75 / 600) loss: 4.622555
# (Epoch 4 / 30) train acc: 0.206000; val_acc: 0.117000
# (Iteration 80 / 600) loss: 4.161080
# (Iteration 85 / 600) loss: 3.908266
# (Iteration 90 / 600) loss: 3.584229
# (Iteration 95 / 600) loss: 3.584308
# (Epoch 5 / 30) train acc: 0.233000; val_acc: 0.127000
# (Iteration 100 / 600) loss: 3.812888
# (Iteration 105 / 600) loss: 3.183605
# (Iteration 110 / 600) loss: 3.908622
# (Iteration 115 / 600) loss: 3.976282
# (Epoch 6 / 30) train acc: 0.260000; val_acc: 0.128000
# (Iteration 120 / 600) loss: 3.908665
# (Iteration 125 / 600) loss: 3.463260
# (Iteration 130 / 600) loss: 3.894030
# (Iteration 135 / 600) loss: 3.475644
# (Epoch 7 / 30) train acc: 0.268000; val_acc: 0.130000
# (Iteration 140 / 600) loss: 3.469301
# (Iteration 145 / 600) loss: 2.952128
# (Iteration 150 / 600) loss: 3.472409
# (Iteration 155 / 600) loss: 2.846412
# (Epoch 8 / 30) train acc: 0.284000; val_acc: 0.146000
# (Iteration 160 / 600) loss: 2.797511
# (Iteration 165 / 600) loss: 3.094856
# (Iteration 170 / 600) loss: 2.553217
# (Iteration 175 / 600) loss: 3.120477
# (Epoch 9 / 30) train acc: 0.298000; val_acc: 0.147000
# (Iteration 180 / 600) loss: 2.216022
# (Iteration 185 / 600) loss: 3.264706
# (Iteration 190 / 600) loss: 2.762266
# (Iteration 195 / 600) loss: 2.773446
# (Epoch 10 / 30) train acc: 0.305000; val_acc: 0.148000
# (Iteration 200 / 600) loss: 2.762346
# (Iteration 205 / 600) loss: 2.943836
# (Iteration 210 / 600) loss: 2.623978
# (Iteration 215 / 600) loss: 2.843595
# (Epoch 11 / 30) train acc: 0.318000; val_acc: 0.146000
# (Iteration 220 / 600) loss: 2.486944
# (Iteration 225 / 600) loss: 2.732489
# (Iteration 230 / 600) loss: 2.704226
# (Iteration 235 / 600) loss: 2.903122
# (Epoch 12 / 30) train acc: 0.316000; val_acc: 0.142000
# (Iteration 240 / 600) loss: 2.401231
# (Iteration 245 / 600) loss: 2.637694
# (Iteration 250 / 600) loss: 2.315060
# (Iteration 255 / 600) loss: 2.183796
# (Epoch 13 / 30) train acc: 0.330000; val_acc: 0.147000
# (Iteration 260 / 600) loss: 2.792029
# (Iteration 265 / 600) loss: 2.074503
# (Iteration 270 / 600) loss: 2.522797
# (Iteration 275 / 600) loss: 2.274133
# (Epoch 14 / 30) train acc: 0.350000; val_acc: 0.159000
# (Iteration 280 / 600) loss: 2.430633
# (Iteration 285 / 600) loss: 2.362383
# (Iteration 290 / 600) loss: 2.077008
# (Iteration 295 / 600) loss: 2.450445
# (Epoch 15 / 30) train acc: 0.366000; val_acc: 0.150000
# (Iteration 300 / 600) loss: 2.809910
# (Iteration 305 / 600) loss: 2.309094
# (Iteration 310 / 600) loss: 1.971977
# (Iteration 315 / 600) loss: 2.280636
# (Epoch 16 / 30) train acc: 0.368000; val_acc: 0.151000
# (Iteration 320 / 600) loss: 2.164995
# (Iteration 325 / 600) loss: 2.346983
# (Iteration 330 / 600) loss: 1.614456
# (Iteration 335 / 600) loss: 1.935436
# (Epoch 17 / 30) train acc: 0.388000; val_acc: 0.151000
# (Iteration 340 / 600) loss: 1.766661
# (Iteration 345 / 600) loss: 2.190699
# (Iteration 350 / 600) loss: 2.025449
# (Iteration 355 / 600) loss: 1.788022
# (Epoch 18 / 30) train acc: 0.402000; val_acc: 0.152000
# (Iteration 360 / 600) loss: 2.354755
# (Iteration 365 / 600) loss: 1.971849
# (Iteration 370 / 600) loss: 2.064599
# (Iteration 375 / 600) loss: 2.318948
# (Epoch 19 / 30) train acc: 0.411000; val_acc: 0.160000
# (Iteration 380 / 600) loss: 2.944897
# (Iteration 385 / 600) loss: 2.007141
# (Iteration 390 / 600) loss: 2.513806
# (Iteration 395 / 600) loss: 1.974098
# (Epoch 20 / 30) train acc: 0.421000; val_acc: 0.159000
# (Iteration 400 / 600) loss: 2.028273
# (Iteration 405 / 600) loss: 2.042079
# (Iteration 410 / 600) loss: 2.193915
# (Iteration 415 / 600) loss: 1.735170
# (Epoch 21 / 30) train acc: 0.424000; val_acc: 0.154000
# (Iteration 420 / 600) loss: 2.189214
# (Iteration 425 / 600) loss: 2.370831
# (Iteration 430 / 600) loss: 2.116456
# (Iteration 435 / 600) loss: 1.611840
# (Epoch 22 / 30) train acc: 0.438000; val_acc: 0.152000
# (Iteration 440 / 600) loss: 2.281920
# (Iteration 445 / 600) loss: 2.078696
# (Iteration 450 / 600) loss: 1.928092
# (Iteration 455 / 600) loss: 1.711477
# (Epoch 23 / 30) train acc: 0.442000; val_acc: 0.153000
# (Iteration 460 / 600) loss: 2.314850
# (Iteration 465 / 600) loss: 1.930799
# (Iteration 470 / 600) loss: 1.789848
# (Iteration 475 / 600) loss: 1.926537
# (Epoch 24 / 30) train acc: 0.455000; val_acc: 0.162000
# (Iteration 480 / 600) loss: 2.523438
# (Iteration 485 / 600) loss: 1.968654
# (Iteration 490 / 600) loss: 1.734151
# (Iteration 495 / 600) loss: 2.034383
# (Epoch 25 / 30) train acc: 0.463000; val_acc: 0.163000
# (Iteration 500 / 600) loss: 2.296692
# (Iteration 505 / 600) loss: 1.855269
# (Iteration 510 / 600) loss: 1.769993
# (Iteration 515 / 600) loss: 1.800462
# (Epoch 26 / 30) train acc: 0.469000; val_acc: 0.162000
# (Iteration 520 / 600) loss: 1.722767
# (Iteration 525 / 600) loss: 1.657140
# (Iteration 530 / 600) loss: 1.756390
# (Iteration 535 / 600) loss: 1.830886
# (Epoch 27 / 30) train acc: 0.477000; val_acc: 0.167000
# (Iteration 540 / 600) loss: 2.065245
# (Iteration 545 / 600) loss: 1.635821
# (Iteration 550 / 600) loss: 2.129187
# (Iteration 555 / 600) loss: 1.704255
# (Epoch 28 / 30) train acc: 0.494000; val_acc: 0.155000
# (Iteration 560 / 600) loss: 2.108614
# (Iteration 565 / 600) loss: 1.597834
# (Iteration 570 / 600) loss: 1.831829
# (Iteration 575 / 600) loss: 1.765036
# (Epoch 29 / 30) train acc: 0.506000; val_acc: 0.163000
# (Iteration 580 / 600) loss: 1.955845
# (Iteration 585 / 600) loss: 1.915798
# (Iteration 590 / 600) loss: 2.264557
# (Iteration 595 / 600) loss: 1.558210
# (Epoch 30 / 30) train acc: 0.516000; val_acc: 0.157000
#
# (Iteration 0 / 600) loss: 143492392.960000
# (Epoch 0 / 30) train acc: 0.114000; val_acc: 0.091000
# (Iteration 5 / 600) loss: 126301757.440000
# (Iteration 10 / 600) loss: 124438681.600000
# (Iteration 15 / 600) loss: 63599861.760000
# (Epoch 1 / 30) train acc: 0.132000; val_acc: 0.105000
# (Iteration 20 / 600) loss: 69666216.960000
# (Iteration 25 / 600) loss: 55420999.680000
# (Iteration 30 / 600) loss: 51821552.640000
# (Iteration 35 / 600) loss: 53387714.560000
# (Epoch 2 / 30) train acc: 0.163000; val_acc: 0.117000
# (Iteration 40 / 600) loss: 30604687.360000
# (Iteration 45 / 600) loss: 29498542.080000
# (Iteration 50 / 600) loss: 27920463.360000
# (Iteration 55 / 600) loss: 21144189.440000
# (Epoch 3 / 30) train acc: 0.203000; val_acc: 0.113000
# (Iteration 60 / 600) loss: 32848358.400000
# (Iteration 65 / 600) loss: 23887882.240000
# (Iteration 70 / 600) loss: 19397358.080000
# (Iteration 75 / 600) loss: 19037820.160000
# (Epoch 4 / 30) train acc: 0.218000; val_acc: 0.121000
# (Iteration 80 / 600) loss: 21492431.360000
# (Iteration 85 / 600) loss: 17316025.600000
# (Iteration 90 / 600) loss: 23552865.280000
# (Iteration 95 / 600) loss: 18804330.240000
# (Epoch 5 / 30) train acc: 0.251000; val_acc: 0.126000
# (Iteration 100 / 600) loss: 15402201.600000
# (Iteration 105 / 600) loss: 16223880.960000
# (Iteration 110 / 600) loss: 18645483.520000
# (Iteration 115 / 600) loss: 21840832.000000
# (Epoch 6 / 30) train acc: 0.276000; val_acc: 0.122000
# (Iteration 120 / 600) loss: 19007443.200000
# (Iteration 125 / 600) loss: 15929214.720000
# (Iteration 130 / 600) loss: 15539237.120000
# (Iteration 135 / 600) loss: 14065331.200000
# (Epoch 7 / 30) train acc: 0.308000; val_acc: 0.114000
# (Iteration 140 / 600) loss: 8542614.400000
# (Iteration 145 / 600) loss: 10447220.480000
# (Iteration 150 / 600) loss: 11621518.080000
# (Iteration 155 / 600) loss: 13410552.320000
# (Epoch 8 / 30) train acc: 0.329000; val_acc: 0.122000
# (Iteration 160 / 600) loss: 11973703.680000
# (Iteration 165 / 600) loss: 10834568.960000
# (Iteration 170 / 600) loss: 9500554.240000
# (Iteration 175 / 600) loss: 11039441.920000
# (Epoch 9 / 30) train acc: 0.346000; val_acc: 0.112000
# (Iteration 180 / 600) loss: 12389735.680000
# (Iteration 185 / 600) loss: 10101544.320000
# (Iteration 190 / 600) loss: 9336227.840000
# (Iteration 195 / 600) loss: 9562283.520000
# (Epoch 10 / 30) train acc: 0.371000; val_acc: 0.112000
# (Iteration 200 / 600) loss: 8881898.240000
# (Iteration 205 / 600) loss: 7362167.040000
# (Iteration 210 / 600) loss: 8565227.520000
# (Iteration 215 / 600) loss: 10774135.040000
# (Epoch 11 / 30) train acc: 0.375000; val_acc: 0.108000
# (Iteration 220 / 600) loss: 5391612.160000
# (Iteration 225 / 600) loss: 8290910.720000
# (Iteration 230 / 600) loss: 11704468.480000
# (Iteration 235 / 600) loss: 5289322.560000
# (Epoch 12 / 30) train acc: 0.416000; val_acc: 0.107000
# (Iteration 240 / 600) loss: 8463809.920000
# (Iteration 245 / 600) loss: 6524670.720000
# (Iteration 250 / 600) loss: 7505894.400000
# (Iteration 255 / 600) loss: 7202159.360000
# (Epoch 13 / 30) train acc: 0.415000; val_acc: 0.114000
# (Iteration 260 / 600) loss: 6383665.920000
# (Iteration 265 / 600) loss: 7096656.640000
# (Iteration 270 / 600) loss: 4817304.640000
# (Iteration 275 / 600) loss: 4845361.280000
# (Epoch 14 / 30) train acc: 0.421000; val_acc: 0.108000
# (Iteration 280 / 600) loss: 6327200.640000
# (Iteration 285 / 600) loss: 5702157.440000
# (Iteration 290 / 600) loss: 6734679.040000
# (Iteration 295 / 600) loss: 7300701.440000
# (Epoch 15 / 30) train acc: 0.441000; val_acc: 0.114000
# (Iteration 300 / 600) loss: 5523818.240000
# (Iteration 305 / 600) loss: 5428712.960000
# (Iteration 310 / 600) loss: 4324281.600000
# (Iteration 315 / 600) loss: 5731020.160000
# (Epoch 16 / 30) train acc: 0.466000; val_acc: 0.112000
# (Iteration 320 / 600) loss: 5385776.000000
# (Iteration 325 / 600) loss: 3408362.240000
# (Iteration 330 / 600) loss: 6763116.800000
# (Iteration 335 / 600) loss: 6685679.360000
# (Epoch 17 / 30) train acc: 0.473000; val_acc: 0.116000
# (Iteration 340 / 600) loss: 3168804.480000
# (Iteration 345 / 600) loss: 4044408.640000
# (Iteration 350 / 600) loss: 6391049.600000
# (Iteration 355 / 600) loss: 3983347.520000
# (Epoch 18 / 30) train acc: 0.480000; val_acc: 0.113000
# (Iteration 360 / 600) loss: 4567768.000000
# (Iteration 365 / 600) loss: 3438538.240000
# (Iteration 370 / 600) loss: 5221360.320000
# (Iteration 375 / 600) loss: 4571801.600000
# (Epoch 19 / 30) train acc: 0.471000; val_acc: 0.111000
# (Iteration 380 / 600) loss: 4448663.040000
# (Iteration 385 / 600) loss: 2845040.960000
# (Iteration 390 / 600) loss: 3193258.240000
# (Iteration 395 / 600) loss: 2768433.600000
# (Epoch 20 / 30) train acc: 0.505000; val_acc: 0.112000
# (Iteration 400 / 600) loss: 3399850.880000
# (Iteration 405 / 600) loss: 4238236.160000
# (Iteration 410 / 600) loss: 2886778.560000
# (Iteration 415 / 600) loss: 2966685.440000
# (Epoch 21 / 30) train acc: 0.521000; val_acc: 0.109000
# (Iteration 420 / 600) loss: 4349320.640000
# (Iteration 425 / 600) loss: 4022858.560000
# (Iteration 430 / 600) loss: 2064238.880000
# (Iteration 435 / 600) loss: 3594207.360000
# (Epoch 22 / 30) train acc: 0.527000; val_acc: 0.115000
# (Iteration 440 / 600) loss: 2650683.680000
# (Iteration 445 / 600) loss: 2963173.120000
# (Iteration 450 / 600) loss: 2121914.080000
# (Iteration 455 / 600) loss: 4491285.760000
# (Epoch 23 / 30) train acc: 0.536000; val_acc: 0.113000
# (Iteration 460 / 600) loss: 4867910.400000
# (Iteration 465 / 600) loss: 2637504.320000
# (Iteration 470 / 600) loss: 3085265.280000
# (Iteration 475 / 600) loss: 2467920.000000
# (Epoch 24 / 30) train acc: 0.562000; val_acc: 0.111000
# (Iteration 480 / 600) loss: 3348372.160000
# (Iteration 485 / 600) loss: 4127942.400000
# (Iteration 490 / 600) loss: 3691300.160000
# (Iteration 495 / 600) loss: 1940077.120000
# (Epoch 25 / 30) train acc: 0.561000; val_acc: 0.114000
# (Iteration 500 / 600) loss: 2279295.360000
# (Iteration 505 / 600) loss: 2286319.200000
# (Iteration 510 / 600) loss: 2888486.720000
# (Iteration 515 / 600) loss: 2907910.720000
# (Epoch 26 / 30) train acc: 0.558000; val_acc: 0.111000
# (Iteration 520 / 600) loss: 1982624.160000
# (Iteration 525 / 600) loss: 2854255.360000
# (Iteration 530 / 600) loss: 2291405.280000
# (Iteration 535 / 600) loss: 3495722.240000
# (Epoch 27 / 30) train acc: 0.580000; val_acc: 0.115000
# (Iteration 540 / 600) loss: 2185866.240000
# (Iteration 545 / 600) loss: 2569496.000000
# (Iteration 550 / 600) loss: 3948894.720000
# (Iteration 555 / 600) loss: 2424789.120000
# (Epoch 28 / 30) train acc: 0.598000; val_acc: 0.122000
# (Iteration 560 / 600) loss: 1973097.600000
# (Iteration 565 / 600) loss: 1913667.840000
# (Iteration 570 / 600) loss: 2450297.920000
# (Iteration 575 / 600) loss: 2805535.360000
# (Epoch 29 / 30) train acc: 0.602000; val_acc: 0.120000
# (Iteration 580 / 600) loss: 1185645.280000
# (Iteration 585 / 600) loss: 1783432.000000
# (Iteration 590 / 600) loss: 2035988.000000
# (Iteration 595 / 600) loss: 1535433.280000
# (Epoch 30 / 30) train acc: 0.606000; val_acc: 0.125000

# %%
# Plot results of weight scale experiment
best_train_accs, bn_best_train_accs = [], []
best_val_accs, bn_best_val_accs = [], []
final_train_loss, bn_final_train_loss = [], []

for ws in weight_scales:
  best_train_accs.append(max(solvers_ws[ws].train_acc_history))
  bn_best_train_accs.append(max(bn_solvers_ws[ws].train_acc_history))
  
  best_val_accs.append(max(solvers_ws[ws].val_acc_history))
  bn_best_val_accs.append(max(bn_solvers_ws[ws].val_acc_history))
  
  final_train_loss.append(np.mean(solvers_ws[ws].loss_history[-100:]))
  bn_final_train_loss.append(np.mean(bn_solvers_ws[ws].loss_history[-100:]))
  
plt.subplot(3, 1, 1)
plt.title('Best val accuracy vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Best val accuracy')
plt.semilogx(weight_scales, best_val_accs, '-o', label='baseline')
plt.semilogx(weight_scales, bn_best_val_accs, '-o', label='batchnorm')
plt.legend(ncol=2, loc='lower right')

plt.subplot(3, 1, 2)
plt.title('Best train accuracy vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Best training accuracy')
plt.semilogx(weight_scales, best_train_accs, '-o', label='baseline')
plt.semilogx(weight_scales, bn_best_train_accs, '-o', label='batchnorm')
plt.legend()

plt.subplot(3, 1, 3)
plt.title('Final training loss vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Final training loss')
plt.semilogx(weight_scales, final_train_loss, '-o', label='baseline')
plt.semilogx(weight_scales, bn_final_train_loss, '-o', label='batchnorm')
plt.legend()
plt.gca().set_ylim(0, 3.5)

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ## Inline Question 1:
# Describe the results of this experiment. How does the scale of weight initialization affect models with/without batch normalization differently, and why?

# %% [markdown]
# ## Answer:

# %% [markdown]
# # Batch normalization and batch size
# We will now run a small experiment to study the interaction of batch normalization and batch size.
#
# The first cell will train 6-layer networks both with and without batch normalization using different batch sizes. The second layer will plot training accuracy and validation set accuracy over time.

# %%
def run_batchsize_experiments(normalization_mode):
    np.random.seed(231)
    # Try training a very deep net with batchnorm
    hidden_dims = [100, 100, 100, 100, 100]
    num_train = 1000
    small_data = {
      'X_train': data['X_train'][:num_train],
      'y_train': data['y_train'][:num_train],
      'X_val': data['X_val'],
      'y_val': data['y_val'],
    }
    n_epochs=10
    weight_scale = 2e-2
    batch_sizes = [5,10,50]
    lr = 10**(-3.5)
    solver_bsize = batch_sizes[0]

    print('No normalization: batch size = ',solver_bsize)
    model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)
    solver = Solver(model, small_data,
                    num_epochs=n_epochs, batch_size=solver_bsize,
                    update_rule='adam',
                    optim_config={
                      'learning_rate': lr,
                    },
                    verbose=False)
    solver.train()
    
    bn_solvers = []
    for i in range(len(batch_sizes)):
        b_size=batch_sizes[i]
        print('Normalization: batch size = ',b_size)
        bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=normalization_mode)
        bn_solver = Solver(bn_model, small_data,
                        num_epochs=n_epochs, batch_size=b_size,
                        update_rule='adam',
                        optim_config={
                          'learning_rate': lr,
                        },
                        verbose=False)
        bn_solver.train()
        bn_solvers.append(bn_solver)
        
    return bn_solvers, solver, batch_sizes

batch_sizes = [5,10,50]
bn_solvers_bsize, solver_bsize, batch_sizes = run_batchsize_experiments('batchnorm')
# Out:
# No normalization: batch size =  5
# Normalization: batch size =  5
# Normalization: batch size =  10
# Normalization: batch size =  50

# %%
plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.train_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.val_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# ## Inline Question 2:
# Describe the results of this experiment. What does this imply about the relationship between batch normalization and batch size? Why is this relationship observed?
#
# ## Answer:

# %% [markdown]
# # Layer Normalization
# Batch normalization has proved to be effective in making networks easier to train, but the dependency on batch size makes it less useful in complex networks which have a cap on the input batch size due to hardware limitations.
#
# Several alternatives to batch normalization have been proposed to mitigate this problem; one such technique is Layer Normalization [4]. Instead of normalizing over the batch, we normalize over the features. In other words, when using Layer Normalization, each feature vector corresponding to a single datapoint is normalized based on the sum of all terms within that feature vector.
#
# [4] [Ba, Jimmy Lei, Jamie Ryan Kiros, and Geoffrey E. Hinton. "Layer Normalization." stat 1050 (2016): 21.](https://arxiv.org/pdf/1607.06450.pdf)

# %% [markdown]
# ## Inline Question 3:
# Which of these data preprocessing steps is analogous to batch normalization, and which is analogous to layer normalization?
#
# 1. Scaling each image in the dataset, so that the RGB channels for each row of pixels within an image sums up to 1.
# 2. Scaling each image in the dataset, so that the RGB channels for all pixels within an image sums up to 1.
# 3. Subtracting the mean image of the dataset from each image in the dataset.
# 4. Setting all RGB values to either 0 or 1 depending on a given threshold.
#
# ## Answer:

# %% [markdown]
# # Layer Normalization: Implementation
#
# Now you'll implement layer normalization. This step should be relatively straightforward, as conceptually the implementation is almost identical to that of batch normalization. One significant difference though is that for layer normalization, we do not keep track of the moving moments, and the testing phase is identical to the training phase, where the mean and variance are directly calculated per datapoint.
#
# Here's what you need to do:
#
# * In `cs231n/layers.py`, implement the forward pass for layer normalization in the function `layernorm_backward`.
#
# Run the cell below to check your results.
# * In `cs231n/layers.py`, implement the backward pass for layer normalization in the function `layernorm_backward`.
#
# Run the second cell below to check your results.
# * Modify `cs231n/classifiers/fc_net.py` to add layer normalization to the `FullyConnectedNet`. When the `normalization` flag is set to `"layernorm"` in the constructor, you should insert a layer normalization layer before each ReLU nonlinearity.
#
# Run the third cell below to run the batch size experiment on layer normalization.

# %%
# Check the training-time forward pass by checking means and variances
# of features both before and after layer normalization   

# Simulate the forward pass for a two-layer network
np.random.seed(231)
N, D1, D2, D3 =4, 50, 60, 3
X = np.random.randn(N, D1)
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)

print('Before layer normalization:')
print_mean_std(a,axis=1)

gamma = np.ones(D3)
beta = np.zeros(D3)
# Means should be close to zero and stds close to one
print('After layer normalization (gamma=1, beta=0)')
a_norm, _ = layernorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=1)

gamma = np.asarray([3.0,3.0,3.0])
beta = np.asarray([5.0,5.0,5.0])
# Now means should be close to beta and stds close to gamma
print('After layer normalization (gamma=', gamma, ', beta=', beta, ')')
a_norm, _ = layernorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=1)
# Out:
# Before layer normalization:
#   means:  [-59.06673243 -47.60782686 -43.31137368 -26.40991744]
#   stds:   [ 10.07429373  28.39478981  35.28360729   4.01831507]
#
# After layer normalization (gamma=1, beta=0)
#   means:  [ -9.62193288e-16   2.22044605e-16   7.40148683e-17  -3.70074342e-17]
#   stds:   [ 0.99999995  0.99999999  1.          0.99999969]
#
# After layer normalization (gamma= [ 3.  3.  3.] , beta= [ 5.  5.  5.] )
#   means:  [ 5.  5.  5.  5.]
#   stds:   [ 2.99999985  2.99999998  2.99999999  2.99999907]

# %%
# Gradient check batchnorm backward pass
np.random.seed(231)
N, D = 4, 5
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

ln_param = {}
fx = lambda x: layernorm_forward(x, gamma, beta, ln_param)[0]
fg = lambda a: layernorm_forward(x, a, beta, ln_param)[0]
fb = lambda b: layernorm_forward(x, gamma, b, ln_param)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
da_num = eval_numerical_gradient_array(fg, gamma.copy(), dout)
db_num = eval_numerical_gradient_array(fb, beta.copy(), dout)

_, cache = layernorm_forward(x, gamma, beta, ln_param)
dx, dgamma, dbeta = layernorm_backward(dout, cache)

#You should expect to see relative errors between 1e-12 and 1e-8
print('dx error: ', rel_error(dx_num, dx))
print('dgamma error: ', rel_error(da_num, dgamma))
print('dbeta error: ', rel_error(db_num, dbeta))
# Out:
# dx error:  1.43361616887e-09
# dgamma error:  4.51948954603e-12
# dbeta error:  2.27644501343e-12

# %% [markdown]
# # Layer Normalization and batch size
#
# We will now run the previous batch size experiment with layer normalization instead of batch normalization. Compared to the previous experiment, you should see a markedly smaller influence of batch size on the training history!

# %%
ln_solvers_bsize, solver_bsize, batch_sizes = run_batchsize_experiments('layernorm')

plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Layer Normalization)','Epoch', solver_bsize, ln_solvers_bsize, \
                      lambda x: x.train_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Layer Normalization)','Epoch', solver_bsize, ln_solvers_bsize, \
                      lambda x: x.val_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()
# Out:
# No normalization: batch size =  5
# Normalization: batch size =  5
# Normalization: batch size =  10
# Normalization: batch size =  50

# %% [markdown]
# ## Inline Question 4:
# When is layer normalization likely to not work well, and why?
#
# 1. Using it in a very deep network
# 2. Having a very small dimension of features
# 3. Having a high regularization term
#
#
# ## Answer:
